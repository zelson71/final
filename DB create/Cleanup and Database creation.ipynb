# %%
import pandas as pd
import glob
from ipywidgets.embed import embed_minimal_html

# %%
path = 'Resources/WE_data'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, encoding = 'utf-8')
    li.append(df)

all_wines_df = pd.concat(li, axis=0, ignore_index=True,sort=True)

# %%
all_wines_df.index.name = ('ID')

# %%
#countries = pd.read_csv('Regional\worldcities.csv')

# %%
all_wines_df.head(5)
# Out:
#     alcohol category  country  \
# ID
# 0      13.0    White  Austria
# 1      13.2      Red       US
# 2      15.0      Red    Italy
# 3      14.1      Red       US
# 4      14.1    White       US
#
#                                           description  \
# ID
# 0   Heady, aromatic highlights of candied lemon pe...
# 1   This is among winemaker Cathy Corison's finest...
# 2   Enticing scents of spiced plum, pipe tobacco, ...
# 3   Bright, crunchy red fruit effuses ripeness in ...
# 4   This white has an expert level of intensity an...
#
#                           designation  price  rating      region  \
# ID
# 0                     Ried Kellerberg    NaN      96      Wachau
# 1                     Kronos Vineyard  185.0      95  California
# 2           Vigneto Monte Sant'Urbano   80.0      94      Veneto
# 3                       Foss Vineyard   62.0      94  California
# 4   Dutton Ranch Walker Hill Vineyard   50.0      94  California
#
# ...

# %% [markdown]
# ## Get the shape of the file to see how many Rows we have

# %%
all_wines_df.shape
# Out:
# (248358, 15)

# %% [markdown]
# ## Get info on the dataframe to show how many Nulls are present on multipe columns

# %%
all_wines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248358 entries, 0 to 248357
# Data columns (total 15 columns):
# alcohol         209216 non-null float64
# category        248358 non-null object
# country         248343 non-null object
# description     247241 non-null object
# designation     174046 non-null object
# price           230456 non-null float64
# rating          248358 non-null int64
# region          244672 non-null object
# subregion       208551 non-null object
# subsubregion    102563 non-null object
# title           248358 non-null object
# url             248358 non-null object
# varietal        248358 non-null object
# vintage         239794 non-null float64
# winery          248358 non-null object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 28.4+ MB

# %% [markdown]
# ## Drop Wines with no Price

# %%
all_wines_df = all_wines_df.dropna(subset=['price'],how='all')

# %% [markdown]
# ## Drop Wines with no Country

# %%
all_wines_df = all_wines_df.dropna(subset=['country'],how='all')

# %% [markdown]
# ## Drop Wines with no alcohol information

# %%
all_wines_df = all_wines_df.dropna(subset=['alcohol'],how='all')

# %% [markdown]
# ## Drop wines without Vintage and Varietal information

# %%
all_wines_df = all_wines_df.dropna(subset=['varietal'],how='all')
all_wines_df = all_wines_df.dropna(subset=['vintage'],how='all')

# %% [markdown]
# ## Get the info again to see how we are doing

# %%
all_wines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192053 entries, 1 to 248357
# Data columns (total 15 columns):
# alcohol         192053 non-null float64
# category        192053 non-null object
# country         192053 non-null object
# description     191277 non-null object
# designation     134595 non-null object
# price           192053 non-null float64
# rating          192053 non-null int64
# region          188850 non-null object
# subregion       159054 non-null object
# subsubregion    81516 non-null object
# title           192053 non-null object
# url             192053 non-null object
# varietal        192053 non-null object
# vintage         192053 non-null float64
# winery          192053 non-null object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 23.4+ MB

# %% [markdown]
# ## Copy data from subregion or subsubregion to the region if it is null

# %%
all_wines_df.loc[all_wines_df['region'].isnull(),'region'] = all_wines_df['subregion']

all_wines_df.loc[all_wines_df['region'].isnull(),'region'] = all_wines_df['subsubregion']

# %%
sum(pd.isnull(all_wines_df['region']))
# Out:
# 6

# %%
all_wines_df.head()
# Out:
#     alcohol category  country  \
# ID
# 1      13.2      Red       US
# 2      15.0      Red    Italy
# 3      14.1      Red       US
# 4      14.1    White       US
# 5      13.5    White  Austria
#
#                                           description  \
# ID
# 1   This is among winemaker Cathy Corison's finest...
# 2   Enticing scents of spiced plum, pipe tobacco, ...
# 3   Bright, crunchy red fruit effuses ripeness in ...
# 4   This white has an expert level of intensity an...
# 5   Yeast, celery and a hint of cream make for an ...
#
#                           designation  price  rating      region  \
# ID
# 1                     Kronos Vineyard  185.0      95  California
# 2           Vigneto Monte Sant'Urbano   80.0      94      Veneto
# 3                       Foss Vineyard   62.0      94  California
# 4   Dutton Ranch Walker Hill Vineyard   50.0      94  California
# 5                             Spiegel   34.0      94      Wagram
#
# ...

# %%
all_wines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192053 entries, 1 to 248357
# Data columns (total 15 columns):
# alcohol         192053 non-null float64
# category        192053 non-null object
# country         192053 non-null object
# description     191277 non-null object
# designation     134595 non-null object
# price           192053 non-null float64
# rating          192053 non-null int64
# region          192047 non-null object
# subregion       159054 non-null object
# subsubregion    81516 non-null object
# title           192053 non-null object
# url             192053 non-null object
# varietal        192053 non-null object
# vintage         192053 non-null float64
# winery          192053 non-null object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 28.4+ MB

# %% [markdown]
# ## Delete Rows where the region has not been populated to this point

# %%
all_wines_df[all_wines_df['region'].isnull()]
# Out:
#         alcohol category       country  \
# ID
# 26         13.5      Red  South Africa
# 148        13.5      Red  South Africa
# 293        13.5      Red  South Africa
# 451        13.0    White  South Africa
# 642        14.0      Red  South Africa
# 209474     13.5    White  South Africa
#
#                                               description designation  price  \
# ID
# 26      Soft earthy spice and sweet cured-bacon aromas...       Vrede   55.0
# 148     There's an herbal edge right upfront on the no...       Vrede   50.0
# 293     Pronounced aromas of mentholated herbs and fyn...         NaN   50.0
# 451     There's a beautiful floral lift to the nose of...         NaN   41.0
# 642     There's a mentholated lift to the nose of this...         NaN   58.0
# 209474  Aromas of apple skin, beesway, musk melon and ...         NaN   20.0
#
#         rating region subregion subsubregion  \
# ID
# 26          94    NaN       NaN          NaN
# ...

# %%
all_wines_df = all_wines_df.dropna(subset=['region'],how='all')

# %%
sum(pd.isnull(all_wines_df['subregion']))
# Out:
# 32993

# %%
all_wines_df[all_wines_df['subregion'].isnull()]
# Out:
#         alcohol category  country  \
# ID
# 5          13.5    White  Austria
# 6          13.5    White  Austria
# 7          12.0    White  Austria
# 8          13.5    White  Austria
# 13         13.5    White  Austria
# ...         ...      ...      ...
# 248321      9.5    White  Germany
# 248335     11.5    White  Germany
# 248339      7.5    White  Germany
# 248341      7.5    White  Germany
# 248357      8.0    White  Germany
#
#                                               description  \
# ID
# 5       Yeast, celery and a hint of cream make for an ...
# 6       Subtle hints of mace and pepper give the nose ...
# 7       Slightly cloudy but with an immensely aromatic...
# 8       A hint of toasted hazelnut glints richly from ...
# 13      Earth, yeast and celery salt promise a savory,...
# ...                                                   ...
# 248321  A top-notch effort, this wine blends fruit and...
# 248335  A stunning, close to dry Riesling from Von Sch...
# ...

# %%
sum(pd.isnull(all_wines_df['subsubregion']))
# Out:
# 110531

# %%
df.isnull().sum(axis=0)
# Out:
# alcohol         3067
# category           0
# country            0
# description       94
# designation     5120
# price           1079
# rating             0
# region           340
# subregion       2775
# subsubregion    9327
# title              0
# url                0
# varietal           0
# vintage          537
# winery             0
# dtype: int64

# %% [markdown]
# ## Import other files created for use in tableau

# %% [markdown]
# ## Import Bordeau Reds 80-84

# %%
bord_red_80to84_df = pd.read_csv("Regional\mw\Bordeaux_Reds_80-84.csv", encoding = 'utf-8')
bord_red_80to84_df.head(3)
# Out:
#                  filename  record number 1  record number 2  alcohol category  \
# 0  winemag 12001 to 12800             1371            48062     12.0      Red
# 1    winemag 6401 to 7200              440           155577      NaN      Red
# 2    winemag 6401 to 7200              444           155581      NaN      Red
#
#   country                                        description designation  \
# 0  France  Mushroom and plum aromas followed by coffee an...         NaN
# 1  France  This very ripe wine tastes of supermature grap...         NaN
# 2  France  Lean and rather dry, this has old wood and lea...      Hyppos
#
#    price  rating  ...  region longitude           subregion  \
# 0      8      80  ...          -0.57918            Bordeaux
# 1     20      80  ...          -0.57918  Bordeaux Supérieur
# 2     25      80  ...          -0.57918  Bordeaux Supérieur
#
#    subregion coordinates   subregion latitude  subregion longitude  \
# ...

# %% [markdown]
# ## Import Bordeau Reds 85-89

# %%
bord_red_85to89_df = pd.read_csv("Regional\mw\Bordeaux_Reds_85-89.csv", encoding = 'utf-8')
bord_red_85to89_df.head(3)
# Out:
#            filename  record number 1  record number 2  alcohol category  \
# 0  winemag 1 to 800             3893             3893     13.0      Red
# 1  winemag 1 to 800             3894             3894     14.0      Red
# 2  winemag 1 to 800             3927             3927     12.5      Red
#
#   country                                        description  \
# 0  France  Fruity and juicy, this forward, no-wood wine w...
# 1  France  Firm and structured, this mostly Merlot blend ...
# 2  France  This smoky wine is hard around the edges. It h...
#
#                   designation  price  rating  ...  region longitude  \
# 0                         NaN     18      85  ...          -0.57918
# 1        Château Bourdieu N°1     35      85  ...          -0.57918
# 2  Demoiselles de Chantemerle     22      85  ...          -0.57918
#
#                  subregion  subregion coordinates   subregion latitude  \
# 0  Blaye Cotes de Bordeaux  44.8377890, -0.5791800           44.837789
# ...

# %% [markdown]
# ## Import Bordeau Reds 90-94

# %%
bord_red_90to94_df = pd.read_csv("Regional\mw\Bordeaux_Reds_90-94.csv", encoding = 'utf-8')
bord_red_90to94_df.head(3)
# Out:
#                filename  record number 1  record number 2  alcohol category  \
# 0  winemag 5601 to 6400            15538           155009     12.5      Red
# 1  winemag 5601 to 6400             5786           145257     13.5      Red
# 2  winemag 4801 to 5600            14725           138618     13.0      Red
#
#   country                                        description designation  \
# 0  France  While this wine has the richness and warmth of...         NaN
# 1  France  A rich, bold wine full of wood flavors that ar...         NaN
# 2  France  This is a wine with potential. It has weight a...         NaN
#
#    price  rating  ...  region longitude                subregion  \
# 0      8      90  ...          -0.57918  Blaye Cotes de Bordeaux
# 1     10      90  ...          -0.57918  Blaye Cotes de Bordeaux
# 2     10      90  ...          -0.57918                 Bordeaux
#
#    subregion coordinates   subregion latitude  subregion longitude  \
# ...

# %% [markdown]
# ## Import Bordeau Reds 95-100

# %%
bord_red_95to100_df = pd.read_csv("Regional\mw\Bordeaux_Reds_95-100.csv", encoding = 'utf-8')
bord_red_95to100_df.head(3)
# Out:
#                  filename  record number 1  record number 2  alcohol category  \
# 0     winemag 801 to 1600             9948           211991     13.0      Red
# 1  winemag 11201 to 12000             2410            33359      NaN      Red
# 2  winemag 12001 to 12800              924            47615      NaN      Red
#
#   country                                        description designation  \
# 0  France  There is a tough, tannic core to this otherwis...         NaN
# 1  France  It may have had a few winemaking controversies...         NaN
# 2  France  Here is a huge ripe and luxurious wine, with g...         NaN
#
#    price  rating  ...  region longitude     subregion  subregion coordinates   \
# 0     30      95  ...          -0.57918       Margaux  45.0420350, -0.6775190
# 1     40      95  ...          -0.57918       Margaux  45.0420350, -0.6775190
# 2     40      95  ...          -0.57918  Saint-Julien   46.0260260, 4.6530810
#
# ...

# %% [markdown]
# ## Import California Cabernet 80-84

# %%
cali_cab_80to84_df = pd.read_csv("Regional\mw\California_Cabernet_80-84.csv", encoding = 'utf-8')
cali_cab_80to84_df.head(3)
# Out:
#                  filename  record number 1  record number 2  alcohol category  \
# 0    winemag 4801 to 5600            12945           136838     15.1      Red
# 1    winemag 8801 to 9600            15455           232436     14.3      Red
# 2  winemag 10401 to 11200             8969            24231     14.5      Red
#
#   country                                        description    designation  \
# 0      US  Containing all red Bordeaux varieties except M...   Commonwealth
# 1      US  This is the winery's Bordeaux blend. It's not ...     Methuselah
# 2      US  Murphy-Goode has a history of producing qualit...  All In Claret
#
#    price  rating  ...  subregion lon          subsubregion  \
# 0     40      80  ...    -117.888977           South Coast
# 1     36      80  ...    -120.654502  Santa Barbara County
# 2     45      80  ...    -122.458036      Alexander Valley
#
#        subsubregion lat lon subsubregion lat  subsubregion lon  \
# ...

# %% [markdown]
# ## Import California Cabernet 85-89

# %%
cali_cab_85to89_df = pd.read_csv("Regional\mw\California_Cabernet_85-89.csv", encoding = 'utf-8')
cali_cab_85to89_df.head(3)
# Out:
#                  filename  record number 1  record number 2  alcohol category  \
# 0  winemag 10401 to 11200            353.0          15615.0     14.0      Red
# 1  winemag 10401 to 11200           2811.0          18073.0     14.3      Red
# 2  winemag 11201 to 12000           5023.0          35972.0     13.5      Red
#
#   country                                        description  \
# 0      US  The grapes had no problem getting ripe, to jud...
# 1      US  This Bordeaux blend is pretty good, showing po...
# 2      US  Enjoy this brawny wine with a nice steak to so...
#
#                                          designation  price  rating  ...  \
# 0  Limited Estate Reserve Tatria Meritage Red Tab...   36.0    85.0  ...
# 1                                   Cuvée de la Luna   30.0    85.0  ...
# 2                                   Wild Card Claret   19.0    85.0  ...
#
#    subregion lon      subsubregion      subsubregion lat lon subsubregion lat  \
# ...

# %% [markdown]
# ## Import California Cabernet 90-94

# %%
cali_cab_90to94_df = pd.read_csv("Regional\mw\California_Cabernet_90-94.csv", encoding = 'utf-8')
cali_cab_90to94_df.head(3)
# Out:
#            filename  record number 1  record number 2  alcohol category  \
# 0  winemag 1 to 800             1028             1028     14.5      Red
# 1  winemag 1 to 800             1324             1324     14.0      Red
# 2  winemag 1 to 800             2473             2473     14.5      Red
#
#   country                                        description  \
# 0      US  From an estate vineyard this combines 60% Merl...
# 1      US  Ripe and ready aromas of black cherry, wood sp...
# 2      US  This hearty red wine is a blend of 57% Caberne...
#
#                designation  price  rating  ...  subregion lon  \
# 0  Bennett Mountain Estate   75.0      90  ...    -122.458036
# 1            Rosso di Sera   28.0      90  ...    -120.654502
# 2           The Discussion  140.0      90  ...    -122.265389
#
#                     subsubregion      subsubregion lat lon subsubregion lat  \
# 0                 Bennett Valley  38.4404672, -122.6766527        38.440467
# ...

# %% [markdown]
# ## Import California Cabernet 95-100

# %%
cali_cab_95to100_df = pd.read_csv("Regional\mw\California_Cabernet_95-100.csv", encoding = 'utf-8')
cali_cab_95to100_df.head(3)
# Out:
#            filename  record number 1  record number 2  alcohol category  \
# 0  winemag 1 to 800             2022             2022     15.2      Red
# 1  winemag 1 to 800             2235             2235     15.2      Red
# 2  winemag 1 to 800             6040             6040     13.8      Red
#
#   country                                        description  \
# 0      US  This is a peppery, spicy wine that has a leath...
# 1      US  A woody and herbal nose follows through to the...
# 2      US  The nose on this blend of 61% Cabernet Sauvign...
#
#                            designation  price  rating  ...  subregion lon  \
# 0  Murasaki Estate Bottled Proprietary    280      95  ...    -122.265389
# 1                 Rindo Estate Bottled    130      95  ...    -122.265389
# 2                       Piocho Reserve     32      95  ...    -120.654502
#
#                     subsubregion      subsubregion lat lon subsubregion lat  \
# ...

# %% [markdown]
# ## Import California Chardonnay 80-84

# %%
cali_chard_80to84_df = pd.read_csv("Regional\mw\California_Chardonnay_80-84.csv", encoding = 'utf-8')
cali_chard_80to84_df.head(3)
# Out:
#                  filename  record number 1  record number 2  alcohol category  \
# 0  winemag 10401 to 11200             4228            19490     13.9    White
# 1  winemag 10401 to 11200            11642            26904      NaN    White
# 2  winemag 10401 to 11200            13596            28858      NaN    White
#
#   country                                        description designation  \
# 0      US  Weak and vegetal, with just the barest note of...         NaN
# 1      US  Has a persistent vegetal smell and taste, desp...         NaN
# 2      US  Dry and acidic, with an unclean finish, this i...         NaN
#
#    price  rating  ... subregion lon        subsubregion  \
# 0    9.0      80  ...   -123.438353    Mendocino County
# 1   18.0      80  ...   -122.265389  Oak Knoll District
# 2   12.0      80  ...   -123.438353    Mendocino County
#
#        subsubregion lat lon subsubregion lat  subsubregion lon  \
# 0  39.3366700, -123.3000000         39.33667        -123.30000
# ...

# %% [markdown]
# ## Import California Chardonnay 85-89

# %%
cali_chard_85to89_df = pd.read_csv("Regional\mw\California_Chardonnay_85-89.csv", encoding = 'utf-8')
cali_chard_85to89_df.head(3)
# Out:
#            filename  record number 1  record number 2  alcohol category  \
# 0  winemag 1 to 800             5817             5817    14.68    White
# 1  winemag 1 to 800            10191            10191    12.50    White
# 2  winemag 1 to 800            10214            10214    13.80    White
#
#   country                                        description designation  \
# 0      US  This is a good, basic wine with modest amounts...   Buttercup
# 1      US  Aromas of orange blossom and mandarin pith sho...         NaN
# 2      US  This wine is quietly floral with a thick entry...         NaN
#
#    price  rating  ... subregion lon   subsubregion      subsubregion lat lon  \
# 0   21.0      85  ...   -122.201107           Lodi  38.1341477, -121.2722194
# 1   10.0      85  ...   -120.654502  Central Coast  35.6368759, -120.6545022
# 2   24.0      85  ...   -122.341529       Carneros  38.2630002, -122.3415289
#
#   subsubregion lat  subsubregion lon  \
# ...

# %% [markdown]
# ## Import California Chardonnay 90-94

# %%
cali_chard_90to94_df = pd.read_csv("Regional\mw\California_Chardonnay_90-94.csv", encoding = 'utf-8')
cali_chard_90to94_df.head(3)
# Out:
#            filename  record number 1  record number 2  alcohol category  \
# 0  winemag 1 to 800            787.0            787.0     14.3    White
# 1  winemag 1 to 800            788.0            788.0     14.2    White
# 2  winemag 1 to 800            904.0            904.0     13.9    White
#
#   country                                        description  \
# 0      US  Caramelized apple and crème brûlée flavors mak...
# 1      US  This is a floral, concentrated white wine. The...
# 2      US  This medium-bodied wine is subtle on the nose,...
#
#                designation  price  rating  ... subregion lon  \
# 0      Strata Estate Grown   40.0    90.0  ...   -122.458036
# 1             Estate Grown   22.0    90.0  ...   -122.265389
# 2  Estate Bottled Old Head   15.0    90.0  ...   -122.201107
#
#            subsubregion      subsubregion lat lon subsubregion lat  \
# 0  Russian River Valley  38.9119799, -123.0537083        38.911980
# ...

# %% [markdown]
# ## Import California Chardonnay 95-100

# %%
cali_chard_95to100_df = pd.read_csv("Regional\mw\California_Chardonnay_95-100.csv", encoding = 'utf-8')
cali_chard_95to100_df.head(3)
# Out:
#            filename  record number 1  record number 2  alcohol category  \
# 0  winemag 1 to 800              157              157     14.4    White
# 1  winemag 1 to 800              170              170     14.5    White
# 2  winemag 1 to 800             2218             2218     14.3    White
#
#   country                                        description     designation  \
# 0      US  This has gorgeous aromas of ginger and crushed...     Gap's Crown
# 1      US  This lovely vineyard-designate is expertly put...  Toyon Vineyard
# 2      US  Medium bodied and gritty on the palate, this h...       Old Wente
#
#    price  rating  ... subregion lon          subsubregion  \
# 0     58      95  ...   -122.458036          Sonoma Coast
# 1    125      95  ...   -122.341529          Los Carneros
# 2     55      95  ...   -122.458036  Russian River Valley
#
#        subsubregion lat lon subsubregion lat  subsubregion lon  \
# 0  38.5779555, -122.9888319        38.577956       -122.988832
# ...

# %% [markdown]
# # French Chardonnay's

# %% [markdown]
# ## Import French Chardonnay 80-84

# %%
french_chard_80to84_df = pd.read_csv("Regional\mw\French_Chardonnay_80-84.csv", encoding = 'utf-8')
french_chard_80to84_df.head(3)
# Out:
#                  filename  record number 1  record number 2  alcohol category  \
# 0  winemag 12001 to 12800             8162            54853     12.7    White
# 1  winemag 10401 to 11200             4207            19469      NaN    White
# 2    winemag 8001 to 8800             5384           191789      NaN    White
#
#   country                                        description designation  \
# 0  France                                                NaN      Chasan
# 1  France  Rather rustic flavors, but there is some green...  Chardonnay
# 2  France  Way too much wood, all toast, spice and green ...        Cray
#
#    price  rating  ...  region longitude         subregion  \
# 0      6      80  ...          3.258363  Vin de Pays d'Oc
# 1     10      80  ...          3.258363  Vin de Pays d'Oc
# 2     23      80  ...          4.383722       Viré-Clessé
#
#   subregion coordinates   subregion latitude  subregion longitude  \
# ...

# %% [markdown]
# ## Import French Chardonnay 85-89

# %%
french_chard_85to89_df = pd.read_csv("Regional\mw\French_Chardonnay_85-89.csv", encoding = 'utf-8')
french_chard_85to89_df.head(3)
# Out:
#                  filename  record number 1  record number 2  alcohol category  \
# 0  winemag 11201 to 12000             6511            37460      NaN    White
# 1  winemag 12001 to 12800             4761            51452     13.0    White
# 2  winemag 12001 to 12800             4809            51500      NaN    White
#
#   country                                        description  \
# 0  France  Smooth and soft, this wine has a touch of vani...
# 1  France  This Chardonnay starts with tropical notes and...
# 2  France                                                NaN
#
#                        designation  price  rating  ...  region longitude  \
# 0                              NaN      6      85  ...          3.258363
# 1                              NaN      7      85  ...          3.258363
# 2  Vichon Mediterranean Chardonnay      7      85  ...          3.258363
#
#           subregion subregion coordinates   subregion latitude  \
# ...

# %% [markdown]
# ## Import French Chardonnay 90-94

# %%
french_chard_90to94_df = pd.read_csv("Regional\mw\French_Chardonnay_90-94.csv", encoding = 'utf-8')
french_chard_90to94_df.head(3)
# Out:
#                filename  record number 1  record number 2  alcohol category  \
# 0  winemag 2401 to 3200             4535            81955     13.0    White
# 1   winemag 801 to 1600             3212           205255     13.0    White
# 2  winemag 8801 to 9600            11522           228503     14.0    White
#
#   country                                        description  \
# 0  France  Made by major Chablis producer Jean-Marc Broca...
# 1  France  Produced by major Chablis producer Jean-Marc B...
# 2  France  This is a terrific Chardonnay from Limoux, an ...
#
#                     designation  price  rating  ...  region longitude  \
# 0  Signature Series Premier Cru     15      90  ...          4.383722
# 1                   Premier Cru     15      90  ...          4.383722
# 2            Cuvée de l'Odyssée     15      90  ...          3.258363
#
#   subregion subregion coordinates   subregion latitude  subregion longitude  \
# ...

# %% [markdown]
# ## Import French Chardonnay 95-100

# %%
french_chard_95to100_df = pd.read_csv("Regional\mw\French_Chardonnay_95-100.csv", encoding = 'utf-8')
french_chard_95to100_df.head(3)
# Out:
#                filename  record number 1  record number 2  alcohol category  \
# 0  winemag 3201 to 4000            14777           107657     13.0    White
# 1  winemag 3201 to 4000            14778           107658     13.0    White
# 2  winemag 3201 to 4000            14797           107677     13.0    White
#
#   country                                        description  \
# 0  France  Mineral and flinty at the start, this young wi...
# 1  France  Rich and open, this is a generous, full-throat...
# 2  France  From ripe fruits, in the Pinson style, this is...
#
#                       designation  price  rating  ...  region longitude  \
# 0  Montée de Tonnerre Premier Cru     39      95  ...          4.383722
# 1      Mont de Milieu Premier Cru     42      95  ...          4.383722
# 2          Fourchaume Premier Cru     42      95  ...          4.383722
#
#   subregion subregion coordinates   subregion latitude  subregion longitude  \
# ...

# %% [markdown]
# # ALL Cab and Chard by Rating

# %%
all_cab_chard_by_rating_df = pd.read_csv("Regional\mw\All Cab and Chard by Rating Bucket.csv", encoding = 'utf-8', low_memory=False)
all_cab_chard_by_rating_df.head(3)
# Out:
#   State / Country     Grape Rating Bucket                filename  \
# 0          France  Cabernet         80-84  winemag 12001 to 12800
# 1          France  Cabernet         80-84    winemag 6401 to 7200
# 2          France  Cabernet         80-84    winemag 6401 to 7200
#
#    record number 1  record number 2  alcohol category country  \
# 0             1371            48062     12.0      Red  France
# 1              440           155577      NaN      Red  France
# 2              444           155581      NaN      Red  France
#
#                                          description  ...           subregion  \
# 0  Mushroom and plum aromas followed by coffee an...  ...            Bordeaux
# 1  This very ripe wine tastes of supermature grap...  ...  Bordeaux Supérieur
# 2  Lean and rather dry, this has old wood and lea...  ...  Bordeaux Supérieur
#
#    subregion coordinates   subregion latitude subregion longitude  \
# ...

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## US_French_Cabernet

# %%
US_French_Cab_df = pd.read_csv("Regional/ks/US_French_Cab_Bordeauxs.csv", encoding = 'utf-8')
US_French_Cab_df.head(3)
# Out:
#     ID  alcohol category country  \
# 0    1     13.2      Red      US
# 1   52     14.2      Red      US
# 2  128     14.5      Red      US
#
#                                          description      designation  price  \
# 0  This is among winemaker Cathy Corison's finest...  Kronos Vineyard  185.0
# 1  This bottling by industry veterans John and He...              NaN   35.0
# 2  Inky in the glass, this rich and structured bo...          Reserve   56.0
#
#   price_bin  rating rating_bin      region      subregion subsubregion  \
# 0     $100+      95     95-100  California           Napa   St. Helena
# 1   $25-$50      94      90-94  California  Central Coast  Paso Robles
# 2  $51-$100      94      90-94  California  Central Coast  Paso Robles
#
#                                                title  \
# 0  Corison 2015 Kronos Vineyard Cabernet Sauvigno...
# 1      Falcone 2016 Cabernet Sauvignon (Paso Robles)
# 2  Daou 2016 Reserve Cabernet Sauvignon (Paso Rob...
#
# ...

# %%
US_French_Chardonnay_df = pd.read_csv("Regional/ks/US_French_Chardonnays.csv", encoding = 'utf-8')
US_French_Chardonnay_df.head(3)
# Out:
#    ID  alcohol category country  \
# 0   4     14.1    White      US
# 1  53     13.8    White      US
# 2  74     14.7    White      US
#
#                                          description  \
# 0  This white has an expert level of intensity an...
# 1  This is a structured and remarkable wine, burs...
# 2  This is a grainy, structured and textured whit...
#
#                           designation  price price_bins  rating rating_bin  \
# 0   Dutton Ranch Walker Hill Vineyard   50.0    $25-$50      94      90-94
# 1  Year of the Monkey Single Vineyard   60.0   $51-$100      94      90-94
# 2     Lewis MacGregor Estate Vineyard   65.0   $51-$100      94      90-94
#
#        region    subregion          subsubregion  \
# 0  California       Sonoma          Green Valley
# 1  California  Napa-Sonoma              Carneros
# 2  California       Sonoma  Russian River Valley
#
#                                                title  \
# ...

# %%
master_df = pd.read_csv("Regional/mw/Master File.csv", encoding = 'utf-8')
master_df.head(3)
# Out:
#                  filename  record number 1  record number 2  alcohol category  \
# 0  winemag 12001 to 12800             8941            55632      NaN      Red
# 1    winemag 3201 to 4000              760            93640     13.9      Red
# 2    winemag 6401 to 7200             2156           157293     13.5      Red
#
#   country or state                      grape  \
# 0       California  Cabernet / Bordeaux Blend
# 1       California  Cabernet / Bordeaux Blend
# 2       California  Cabernet / Bordeaux Blend
#
#                                          description designation  price  ...  \
# 0  A bit beefy in the nose, the wine has a distin...         NaN     23  ...
# 1  This wine tastes sweet and grapey, with a soft...      Estate     31  ...
# 2  This tastes like an inexpensive Merlot you ope...         NaN     23  ...
#
#    region longitude subregion    subregion coordinates  subregion latitude  \
# 0       -122.341529  Carneros  38.2630002, -122.3415289             38.263
# ...

# %% [markdown]
# ## Top 50 words

# %%
top_50_words = pd.read_csv("Regional/mw/Top 50 Common Words by Rating Buckets.csv",encoding='utf-8')
top_50_words.head(3)
# Out:
#                   Type of Wine Descriptor   Descriptor Count  \
# 0  California Chardonnay - All        oak             3954.0
# 1  California Chardonnay - All      apple             2568.0
# 2  California Chardonnay - All    vanilla             2138.0
#
#   How Often Descriptor Appears
# 0                          41%
# 1                          27%
# 2                          22%

# %% [markdown]
# ## Katherine Predictions files

# %%
cab_bords_predict_region = pd.read_csv("Regional/ks/Cab_Bords_Predictions_region.csv", encoding = 'utf-8')
cab_bords_predict_region.head(3)
# Out:
#    rating      region  predicted_
# 0      80     America   39.375381
# 1      80    Bordeaux   26.544897
# 2      80  California   30.691183

# %%
cab_bords_predict_subregion = pd.read_csv("Regional/ks/Cab_Bords_Predictions_subregion.csv", encoding = 'utf-8')
cab_bords_predict_region.head(3)
# Out:
#    rating      region  predicted_
# 0      80     America   39.375381
# 1      80    Bordeaux   26.544897
# 2      80  California   30.691183

# %%
chard_prediction_region = pd.read_csv("Regional/ks/Chards_Predictions_region.csv")
chard_prediction_region.head(3)
# Out:
#    rating   region  predicted_
# 0      80   Alsace   29.704847
# 1      80  America   39.091007
# 2      80  Arizona   67.618851

# %%
chard_prediction_subregion = pd.read_csv("Regional/ks/Chards_Predictions_subregion.csv")
chard_prediction_subregion.head(3)
# Out:
#    rating subregion  predicted_
# 0      80    Alsace   21.929043
# 1      80    Arbois   18.215944
# 2      80   Ardèche   24.324093

# %% [markdown]
# ## Create A SQL Connection and Define the Database

# %%
import sqlalchemy
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy_utils import database_exists, create_database

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/Final', echo=False)
session = Session(engine)
if not database_exists(engine.url):
                       create_database(engine.url)
conn = engine.connect()
session = Session(engine)

# %% [markdown]
# ## Export the Dataframes to Tables in the Database

# %%
top_50_words.to_sql("top_50_words",index=True,if_exists='replace',con=engine)

# %% [markdown]
# ## All Wines

# %%
all_wines_df.to_sql("all_wines", index=True, if_exists='replace', con=engine)

# %% [markdown]
# ## Bordeau's

# %%
bord_red_80to84_df.to_sql("bord_reds80to84",index=True,if_exists='replace',con=engine)
bord_red_85to89_df.to_sql("bord_reds85to89",index=True,if_exists='replace',con=engine)
bord_red_90to94_df.to_sql("bord_reds90to94",index=True,if_exists='replace',con=engine)
bord_red_95to100_df.to_sql("bord_reds95to100",index=True,if_exists='replace',con=engine)

# %% [markdown]
# ## California Cabernet's

# %%
cali_cab_80to84_df.to_sql("cali_cab_80to84",index=True,if_exists='replace',con=engine)
cali_cab_85to89_df.to_sql("cali_cab_85to89",index=True,if_exists='replace',con=engine)
cali_cab_90to94_df.to_sql("cali_cab_90to94",index=True,if_exists='replace',con=engine)
cali_cab_95to100_df.to_sql("cali_cab_95to100",index=True,if_exists='replace',con=engine)

# %% [markdown]
# ## California Chardonnay's

# %%
cali_chard_80to84_df.to_sql("cali_chard_80to84",index=True,if_exists='replace',con=engine)
cali_chard_85to89_df.to_sql("cali_chard_85to89",index=True,if_exists='replace',con=engine)
cali_chard_90to94_df.to_sql("cali_chard_90to94",index=True,if_exists='replace',con=engine)
cali_chard_95to100_df.to_sql("cali_chard_95to100",index=True,if_exists='replace',con=engine)

# %% [markdown]
# ## French Chardonnay's

# %%
french_chard_80to84_df.to_sql("french_chard_80to84",index=True,if_exists='replace',con=engine)
french_chard_85to89_df.to_sql("french_chard_85to89",index=True,if_exists='replace',con=engine)
french_chard_90to94_df.to_sql("french_chard_90to94",index=True,if_exists='replace',con=engine)
french_chard_95to100_df.to_sql("french_chard_95to100",index=True,if_exists='replace',con=engine)

# %% [markdown]
# ## All Cabernet and Chardonnay's Table

# %%
all_cab_chard_by_rating_df.to_sql("all_cab_chard_by_rating",index=True,if_exists='replace',con=engine)

# %% [markdown]
# ## Machine Learning CSV Tables

# %%
US_French_Chardonnay_df.to_sql("US_French_Chard", index=True, if_exists='replace',con=engine)
US_French_Cab_df.to_sql("US_French_Cab",index=True, if_exists='replace',con=engine)

# %%
master_df.to_sql("CA_FR_CAB_Chard", index=True,if_exists='replace',con=engine)

# %%
cab_bords_predict_region.to_sql("Cab_Board_Predictions_region",index=True,if_exists='replace',con=engine)
cab_bords_predict_subregion.to_sql("Cab_Board_Predictions_subregion",index=True,if_exists='replace',con=engine)

# %%
chard_prediction_region.to_sql("Chard_Predictions_region",index=True,if_exists='replace',con=engine)
chard_prediction_subregion.to_sql("Chard_Predictions_subregion",index=True,if_exists='replace',con=engine)

# %% [markdown]
# ## DB creation Complete
