# %%
import pandas as pd
import pandas
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import itertools
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
import sqlalchemy as sa
# Out:
# Using TensorFlow backend.

# %%
# Connect to SQL database in Postgres
wine_db = "postgresql://postgres:postgres@localhost:5432/Final"
engine = sa.create_engine(wine_db, echo=False)
conn = engine.connect()

# %%
# Select table and create df
df = pd.read_sql("SELECT * FROM us_french_chards", conn)

# %%
# Make subregion a str
df['subregion'] = df['subregion'].astype(str)

# %%
df
# Out:
#        index      ID  alcohol category country  \
# 0          0       4     14.1    White      US
# 1          1      53     13.8    White      US
# 2          2      74     14.7    White      US
# 3          3     156     14.4    White      US
# 4          4     169     14.5    White      US
# ...      ...     ...      ...      ...     ...
# 13683  13683  248214     14.4    White      US
# 13684  13684  248312     14.5    White      US
# 13685  13685  248330     14.5    White      US
# 13686  13686  248342     15.2    White      US
# 13687  13687  233916     14.3    White      US
#
#                                              description  \
# 0      This white has an expert level of intensity an...
# 1      This is a structured and remarkable wine, burs...
# 2      This is a grainy, structured and textured whit...
# 3      This has gorgeous aromas of ginger and crushed...
# 4      This lovely vineyard-designate is expertly put...
# ...                                                  ...
# 13683  Front-loaded with fruit, this extraordinarily ...
# 13684  This is a great expression of what winemaker R...
# 13685  What a great Chard. Just delicious in palate-f...
# 13686  This is a new winery for me, but one to watch....
# 13687  Heavy and sweet, with flavors of canned peache...
#
#                               designation  price price_bins  rating  \
# 0       Dutton Ranch Walker Hill Vineyard   50.0    $25-$50      94
# 1      Year of the Monkey Single Vineyard   60.0   $51-$100      94
# 2         Lewis MacGregor Estate Vineyard   65.0   $51-$100      94
# 3                             Gap's Crown   58.0   $51-$100      95
# 4                          Toyon Vineyard  125.0      $100+      95
# ...                                   ...    ...        ...     ...
# 13683                  Rosella's Vineyard   44.0    $25-$50      90
# 13684            Camelot Highlands Estate   25.0     $0-$25      91
# 13685               Seco Highlands Estate   30.0    $25-$50      92
# 13686                             Reserve   29.0    $25-$50      92
# 13687                                None   19.0     $0-$25      82
#
#       rating_bin      region      subregion           subsubregion  \
# 0          90-94  California         Sonoma           Green Valley
# 1          90-94  California    Napa-Sonoma               Carneros
# 2          90-94  California         Sonoma   Russian River Valley
# 3         95-100  California         Sonoma           Sonoma Coast
# 4         95-100  California    Napa-Sonoma           Los Carneros
# ...          ...         ...            ...                    ...
# 13683      90-94  California  Central Coast  Santa Lucia Highlands
# 13684      90-94  California  Central Coast     Santa Maria Valley
# 13685      90-94  California  Central Coast            Arroyo Seco
# 13686      90-94  California  Central Coast   Santa Barbara County
# 13687      80-84  California  Central Coast       Livermore Valley
#
#                                                    title  \
# 0      Dutton-Goldfield 2016 Dutton Ranch Walker Hill...
# 1      Donum 2016 Year of the Monkey Single Vineyard ...
# 2      Williams Selyem 2016 Lewis MacGregor Estate Vi...
# 3      Black Kite 2016 Gap's Crown Chardonnay (Sonoma...
# 4      Alpha Omega 2015 Toyon Vineyard Chardonnay (Lo...
# ...                                                  ...
# 13683  Testarossa 2005 Rosella's Vineyard Chardonnay ...
# 13684  Kendall-Jackson 2005 Camelot Highlands Estate ...
# 13685  Kendall-Jackson 2005 Seco Highlands Estate Cha...
# 13686  Addamo 2005 Reserve Chardonnay (Santa Barbara ...
# 13687        Fenestra 2007 Chardonnay (Livermore Valley)
#
#                                                      url    varietal  vintage  \
# 0      https://www.winemag.com/buying-guide/dutton-go...  Chardonnay     2016
# 1      https://www.winemag.com/buying-guide/donum-201...  Chardonnay     2016
# 2      https://www.winemag.com/buying-guide/williams-...  Chardonnay     2016
# 3      https://www.winemag.com/buying-guide/black-kit...  Chardonnay     2016
# 4      https://www.winemag.com/buying-guide/alpha-ome...  Chardonnay     2015
# ...                                                  ...         ...      ...
# 13683  https://www.winemag.com/buying-guide/testaross...  Chardonnay     2005
# 13684  https://www.winemag.com/buying-guide/kendall-j...  Chardonnay     2005
# 13685  https://www.winemag.com/buying-guide/kendall-j...  Chardonnay     2005
# 13686  https://www.winemag.com/buying-guide/addamo-20...  Chardonnay     2005
# 13687  https://www.winemag.com/buying-guide/fenestra-...  Chardonnay     2007
#
#                  winery
# 0      Dutton-Goldfield
# 1                 Donum
# 2       Williams Selyem
# 3            Black Kite
# 4           Alpha Omega
# ...                 ...
# 13683        Testarossa
# 13684   Kendall-Jackson
# 13685   Kendall-Jackson
# 13686            Addamo
# 13687          Fenestra
#
# [13688 rows x 19 columns]

# %%
# Drop unneccessary columns
df = df.drop(['ID', 'index','category', 'country', 'region', 'subsubregion','varietal', 'alcohol', 'description', 'price_bins', 'rating_bin', 'designation', 'title', 'url', 'vintage','winery'], axis=1)
df.head()
# Out:
#    price  rating    subregion
# 0   50.0      94       Sonoma
# 1   60.0      94  Napa-Sonoma
# 2   65.0      94       Sonoma
# 3   58.0      95       Sonoma
# 4  125.0      95  Napa-Sonoma

# %%
# Drop NAs
df = df.dropna(subset=['subregion'])

# %%
# Set X and y
X = df.drop("price", axis=1)
y = df["price"]

# %%
# instantiate labelencoder object
le = LabelEncoder()

# %%
# Gather unique lists of categories
encoded_rating = le.fit(df.rating)
rating_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
rating_name_array = le.classes_
rating_le_array = le.transform(le.classes_)

encoded_subregion = le.fit(df.subregion)
subregion_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
subregion_name_array = le.classes_
subregion_le_array = le.transform(le.classes_)

# Create dataframe of all possible iterations of rating and subregion pairings
predict_list = list(itertools.product(rating_name_array, subregion_name_array))
predict_df = pd.DataFrame(predict_list)
predict_df
# Out:
#        0                              1
# 0     80                         Alsace
# 1     80                         Arbois
# 2     80                        Ardèche
# 3     80                        Arizona
# 4     80                 Auxey-Duresses
# ...   ..                            ...
# 3075  99                        Vougeot
# 3076  99               Washington Other
# 3077  99  Western Connecticut Highlands
# 3078  99              Willamette Valley
# 3079  99                  Yadkin Valley
#
# [3080 rows x 2 columns]

# %%
# instantiate OneHotEncoder
ohe = OneHotEncoder(sparse=False,categories="auto" )

# %%
# apply OneHotEncoder to X
X_ohe = ohe.fit_transform(X) # It returns an numpy array
# print(X_ohe)

# Capture categories in variable
categories = ohe.categories_

# %%
# apply OneHotEncoder to predict_df
predict_X_ohe = ohe.fit_transform(predict_df)
# predict_X_ohe

# %%
# Prepare for train-test-split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_ohe, y, random_state=42)
print(y_test.shape)
print(X_test.shape)
# Out:
# (3422,)
# (3422, 174)

# %%
# Capture # inputs in a variable
input_dims = X_ohe.shape[1]
input_dims
# Out:
# 174

# %%
# Build Sequential Keras model to train data
model = Sequential()

model.add(Dense(128, activation = 'relu', name='dense_1', kernel_initializer='glorot_uniform', input_dim=(input_dims)))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu', name='dense_2', kernel_initializer='glorot_uniform'))
# model.add(Dropout(0.1))
# model.add(Dense(64, activation='relu', name='dense_3', kernel_initializer='glorot_uniform'))
model.add(Dense(1,name='predictions'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               22400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# predictions (Dense)          (None, 1)                 65
# =================================================================
# Total params: 30,721
# Trainable params: 30,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
from numpy import sqrt,asarray

# Compile model
model.compile(optimizer='adam', loss='mse', metrics=['mse','mae','mean_absolute_percentage_error'])

# %%
# from keras.callbacks import EarlyStopping

# %%
# Fit model with training data

# history = model.fit(X_train, y_train, epochs=30, callbacks=[EarlyStopping(patience=5)])
history = model.fit(X_train, y_train, epochs=40, batch_size=5,  verbose=1, validation_split=0.2)
# Out:
# Train on 8212 samples, validate on 2054 samples
# Epoch 1/40
# 8212/8212 [==============================] - 3s 318us/step - loss: 873.4587 - mse: 873.4588 - mae: 12.9864 - mean_absolute_percentage_error: 39.6186 - val_loss: 324.2940 - val_mse: 324.2941 - val_mae: 10.3156 - val_mean_absolute_percentage_error: 33.2764
# Epoch 2/40
# 8212/8212 [==============================] - 2s 267us/step - loss: 440.0408 - mse: 440.0411 - mae: 10.5772 - mean_absolute_percentage_error: 33.0239 - val_loss: 245.1521 - val_mse: 245.1522 - val_mae: 9.7631 - val_mean_absolute_percentage_error: 31.5225
# Epoch 3/40
# 8212/8212 [==============================] - 2s 268us/step - loss: 302.2350 - mse: 302.2348 - mae: 9.9375 - mean_absolute_percentage_error: 32.0532 - val_loss: 227.7462 - val_mse: 227.7461 - val_mae: 9.6883 - val_mean_absolute_percentage_error: 31.1543
# Epoch 4/40
# 8212/8212 [==============================] - 2s 265us/step - loss: 260.9307 - mse: 260.9307 - mae: 9.6756 - mean_absolute_percentage_error: 31.4310 - val_loss: 211.8943 - val_mse: 211.8945 - val_mae: 9.4967 - val_mean_absolute_percentage_error: 30.6120
# Epoch 5/40
# 8212/8212 [==============================] - 2s 259us/step - loss: 249.5352 - mse: 249.5352 - mae: 9.4740 - mean_absolute_percentage_error: 30.9104 - val_loss: 207.5201 - val_mse: 207.5201 - val_mae: 9.5057 - val_mean_absolute_percentage_error: 31.1942
# Epoch 6/40
# 8212/8212 [==============================] - 2s 266us/step - loss: 232.8139 - mse: 232.8140 - mae: 9.4481 - mean_absolute_percentage_error: 30.9024 - val_loss: 201.5480 - val_mse: 201.5480 - val_mae: 9.4837 - val_mean_absolute_percentage_error: 31.1455
# Epoch 7/40
# 8212/8212 [==============================] - 2s 269us/step - loss: 220.8800 - mse: 220.8800 - mae: 9.3393 - mean_absolute_percentage_error: 30.5725 - val_loss: 218.0214 - val_mse: 218.0214 - val_mae: 10.0996 - val_mean_absolute_percentage_error: 35.4926
# Epoch 8/40
# 8212/8212 [==============================] - 2s 271us/step - loss: 218.1697 - mse: 218.1696 - mae: 9.2397 - mean_absolute_percentage_error: 30.3233 - val_loss: 206.0894 - val_mse: 206.0895 - val_mae: 9.8723 - val_mean_absolute_percentage_error: 34.6581
# Epoch 9/40
# 8212/8212 [==============================] - 2s 269us/step - loss: 217.2624 - mse: 217.2624 - mae: 9.2333 - mean_absolute_percentage_error: 30.4461 - val_loss: 214.4405 - val_mse: 214.4404 - val_mae: 9.9396 - val_mean_absolute_percentage_error: 33.9356
# Epoch 10/40
# 8212/8212 [==============================] - 2s 261us/step - loss: 212.6854 - mse: 212.6856 - mae: 9.2281 - mean_absolute_percentage_error: 30.3240 - val_loss: 217.9057 - val_mse: 217.9058 - val_mae: 9.8429 - val_mean_absolute_percentage_error: 33.3190
# Epoch 11/40
# 8212/8212 [==============================] - 2s 265us/step - loss: 205.7734 - mse: 205.7732 - mae: 9.1318 - mean_absolute_percentage_error: 30.0331 - val_loss: 211.7589 - val_mse: 211.7589 - val_mae: 9.5709 - val_mean_absolute_percentage_error: 30.8943
# Epoch 12/40
# 8212/8212 [==============================] - 2s 262us/step - loss: 205.6817 - mse: 205.6819 - mae: 9.1637 - mean_absolute_percentage_error: 30.2830 - val_loss: 215.4565 - val_mse: 215.4565 - val_mae: 9.5334 - val_mean_absolute_percentage_error: 30.8798
# Epoch 13/40
# 8212/8212 [==============================] - 2s 268us/step - loss: 200.6965 - mse: 200.6967 - mae: 9.1192 - mean_absolute_percentage_error: 30.0429 - val_loss: 218.4519 - val_mse: 218.4518 - val_mae: 9.5466 - val_mean_absolute_percentage_error: 31.3521
# Epoch 14/40
# 8212/8212 [==============================] - 2s 268us/step - loss: 204.8264 - mse: 204.8263 - mae: 9.1190 - mean_absolute_percentage_error: 30.2230 - val_loss: 214.9274 - val_mse: 214.9274 - val_mae: 9.5773 - val_mean_absolute_percentage_error: 30.7414
# Epoch 15/40
# 8212/8212 [==============================] - 2s 290us/step - loss: 199.8434 - mse: 199.8435 - mae: 9.0634 - mean_absolute_percentage_error: 30.0332 - val_loss: 230.7036 - val_mse: 230.7035 - val_mae: 9.6805 - val_mean_absolute_percentage_error: 31.6550
# Epoch 16/40
# 8212/8212 [==============================] - 3s 347us/step - loss: 200.0348 - mse: 200.0347 - mae: 9.0661 - mean_absolute_percentage_error: 30.1088 - val_loss: 240.9419 - val_mse: 240.9419 - val_mae: 9.7062 - val_mean_absolute_percentage_error: 31.2274
# Epoch 17/40
# 8212/8212 [==============================] - 3s 379us/step - loss: 202.5744 - mse: 202.5742 - mae: 9.1103 - mean_absolute_percentage_error: 30.1506 - val_loss: 220.4254 - val_mse: 220.4254 - val_mae: 9.5847 - val_mean_absolute_percentage_error: 31.6902
# Epoch 18/40
# 8212/8212 [==============================] - 3s 344us/step - loss: 200.1457 - mse: 200.1458 - mae: 9.0388 - mean_absolute_percentage_error: 30.0336 - val_loss: 220.0970 - val_mse: 220.0970 - val_mae: 9.7548 - val_mean_absolute_percentage_error: 33.3093
# Epoch 19/40
# 8212/8212 [==============================] - 3s 318us/step - loss: 200.0781 - mse: 200.0782 - mae: 9.0444 - mean_absolute_percentage_error: 30.1060 - val_loss: 226.3287 - val_mse: 226.3286 - val_mae: 9.4561 - val_mean_absolute_percentage_error: 30.0694
# Epoch 20/40
# 8212/8212 [==============================] - 3s 306us/step - loss: 199.4489 - mse: 199.4489 - mae: 9.0002 - mean_absolute_percentage_error: 29.8909 - val_loss: 225.7044 - val_mse: 225.7042 - val_mae: 9.8397 - val_mean_absolute_percentage_error: 33.4062
# Epoch 21/40
# 8212/8212 [==============================] - 2s 304us/step - loss: 195.4228 - mse: 195.4230 - mae: 9.0199 - mean_absolute_percentage_error: 30.1185 - val_loss: 252.1014 - val_mse: 252.1013 - val_mae: 9.8836 - val_mean_absolute_percentage_error: 32.3313
# Epoch 22/40
# 8212/8212 [==============================] - 3s 307us/step - loss: 202.2585 - mse: 202.2585 - mae: 9.0223 - mean_absolute_percentage_error: 29.9575 - val_loss: 241.1407 - val_mse: 241.1408 - val_mae: 9.9176 - val_mean_absolute_percentage_error: 33.0456
# Epoch 23/40
# 8212/8212 [==============================] - 3s 309us/step - loss: 202.4481 - mse: 202.4481 - mae: 9.0309 - mean_absolute_percentage_error: 30.0059 - val_loss: 223.8053 - val_mse: 223.8053 - val_mae: 9.6953 - val_mean_absolute_percentage_error: 32.0805
# Epoch 24/40
# 8212/8212 [==============================] - 3s 314us/step - loss: 201.4933 - mse: 201.4933 - mae: 9.0172 - mean_absolute_percentage_error: 30.0920 - val_loss: 229.1499 - val_mse: 229.1499 - val_mae: 9.6879 - val_mean_absolute_percentage_error: 32.3279
# Epoch 25/40
# 8212/8212 [==============================] - 3s 316us/step - loss: 200.5107 - mse: 200.5105 - mae: 9.0550 - mean_absolute_percentage_error: 29.9951 - val_loss: 218.3711 - val_mse: 218.3711 - val_mae: 9.5913 - val_mean_absolute_percentage_error: 31.6720
# Epoch 26/40
# 8212/8212 [==============================] - 3s 323us/step - loss: 199.8192 - mse: 199.8191 - mae: 9.0343 - mean_absolute_percentage_error: 30.0356 - val_loss: 225.0548 - val_mse: 225.0548 - val_mae: 9.5997 - val_mean_absolute_percentage_error: 31.6995
# Epoch 27/40
# 8212/8212 [==============================] - 3s 332us/step - loss: 196.6160 - mse: 196.6162 - mae: 8.9702 - mean_absolute_percentage_error: 29.8986 - val_loss: 221.1666 - val_mse: 221.1667 - val_mae: 9.4710 - val_mean_absolute_percentage_error: 31.3693
# Epoch 28/40
# 8212/8212 [==============================] - 3s 313us/step - loss: 199.2711 - mse: 199.2712 - mae: 9.0434 - mean_absolute_percentage_error: 30.1480 - val_loss: 241.5725 - val_mse: 241.5724 - val_mae: 9.6635 - val_mean_absolute_percentage_error: 31.5246
# Epoch 29/40
# 8212/8212 [==============================] - 3s 313us/step - loss: 192.6736 - mse: 192.6738 - mae: 8.9966 - mean_absolute_percentage_error: 29.8862 - val_loss: 223.3447 - val_mse: 223.3447 - val_mae: 9.5307 - val_mean_absolute_percentage_error: 31.1865
# Epoch 30/40
# 8212/8212 [==============================] - 3s 308us/step - loss: 197.9694 - mse: 197.9694 - mae: 8.9395 - mean_absolute_percentage_error: 29.8408 - val_loss: 222.5311 - val_mse: 222.5311 - val_mae: 9.5288 - val_mean_absolute_percentage_error: 31.3712
# Epoch 31/40
# 8212/8212 [==============================] - 3s 317us/step - loss: 194.6185 - mse: 194.6187 - mae: 8.9308 - mean_absolute_percentage_error: 29.7584 - val_loss: 218.4748 - val_mse: 218.4748 - val_mae: 9.6112 - val_mean_absolute_percentage_error: 31.1896
# Epoch 32/40
# 8212/8212 [==============================] - 3s 327us/step - loss: 197.5125 - mse: 197.5123 - mae: 8.9790 - mean_absolute_percentage_error: 29.8773 - val_loss: 221.9906 - val_mse: 221.9907 - val_mae: 9.6681 - val_mean_absolute_percentage_error: 32.4249
# Epoch 33/40
# 8212/8212 [==============================] - 3s 313us/step - loss: 196.4841 - mse: 196.4840 - mae: 8.9219 - mean_absolute_percentage_error: 29.7373 - val_loss: 211.6756 - val_mse: 211.6756 - val_mae: 9.5857 - val_mean_absolute_percentage_error: 31.3856
# Epoch 34/40
# 8212/8212 [==============================] - 3s 317us/step - loss: 201.4946 - mse: 201.4945 - mae: 8.9915 - mean_absolute_percentage_error: 29.8420 - val_loss: 230.0956 - val_mse: 230.0957 - val_mae: 10.0207 - val_mean_absolute_percentage_error: 34.8245
# Epoch 35/40
# 8212/8212 [==============================] - 3s 314us/step - loss: 194.7455 - mse: 194.7454 - mae: 8.9304 - mean_absolute_percentage_error: 29.9510 - val_loss: 232.1311 - val_mse: 232.1312 - val_mae: 9.7745 - val_mean_absolute_percentage_error: 32.4489
# Epoch 36/40
# 8212/8212 [==============================] - 2s 304us/step - loss: 200.6175 - mse: 200.6174 - mae: 8.9493 - mean_absolute_percentage_error: 29.8479 - val_loss: 207.4977 - val_mse: 207.4978 - val_mae: 9.4227 - val_mean_absolute_percentage_error: 30.3609
# Epoch 37/40
# 8212/8212 [==============================] - 3s 309us/step - loss: 196.1027 - mse: 196.1026 - mae: 8.9632 - mean_absolute_percentage_error: 29.7440 - val_loss: 207.7536 - val_mse: 207.7536 - val_mae: 9.4155 - val_mean_absolute_percentage_error: 30.5843
# Epoch 38/40
# 8212/8212 [==============================] - 2s 304us/step - loss: 196.0136 - mse: 196.0136 - mae: 8.9349 - mean_absolute_percentage_error: 29.7330 - val_loss: 209.2744 - val_mse: 209.2744 - val_mae: 9.6157 - val_mean_absolute_percentage_error: 32.4271
# Epoch 39/40
# 8212/8212 [==============================] - 2s 300us/step - loss: 193.7529 - mse: 193.7530 - mae: 8.9737 - mean_absolute_percentage_error: 30.0989 - val_loss: 217.0489 - val_mse: 217.0489 - val_mae: 9.5367 - val_mean_absolute_percentage_error: 30.8041
# Epoch 40/40
# 8212/8212 [==============================] - 3s 306us/step - loss: 193.7983 - mse: 193.7983 - mae: 8.9322 - mean_absolute_percentage_error: 29.6917 - val_loss: 211.7421 - val_mse: 211.7422 - val_mae: 9.4371 - val_mean_absolute_percentage_error: 30.0168

# %%
# Evaluate error and print MSE, MAE and Mean Absolute Percentage Error
error = model.evaluate(X_test, y_test, verbose=2)

print(f"MSE: {error[0]}")
print(f"MAE: {error[1]}")
print(f"Mean Absolute Percentage Error: {error[2]}")
# Out:
# MSE: 318.8451806028847
# MAE: 318.8451232910156
# Mean Absolute Percentage Error: 9.80766487121582

# %%
# Build plot of training loss and validation loss

# print(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Compare one sample y with a predicted y
test_data = X_test[0]
pred = (model.predict(test_data.reshape(1,174)))
print(f"Predicted Price: {pred}")
print(f"Possible Rating and Subregion {ohe.inverse_transform(X_test[0].reshape(1,-1))}")
print('---------------------------------------------------------------------------')
print(f"Actual Price: {y[0]}")
print(f"Actual Rating: {X.rating[1]}")
print(f"Actual Subregion: {X.subregion[1]}")
# Out:
# Predicted Price: [[23.195192]]
# Possible Rating and Subregion [[87 'Mâcon-Azé']]
# ---------------------------------------------------------------------------
# Actual Price: 50.0
# Actual Rating: 94
# Actual Subregion: Napa-Sonoma

# %%
# Save model
# model.save('model_us_french_Chards_OHE_subregion.h5')

# %%
# Load old model for testing
# from tensorflow.keras.models import load_model
# old_model = load_model('model_us_french_Chards_OHE_subregion.h5')

# %%
# Use to compare predicted price to predicted price of old model

# print(y[0])
# test_data = X_test[0]
# pred = (old_model.predict(test_data.reshape(1,174)))
# print(pred)

# %%
# Show one X value from OHE version of list of possible rate / region combos
test = np.expand_dims(X_ohe[0], axis=0)

# %%
# Make predictions on original dataset

predict_dataset = model.predict(X_ohe)
predict_dataset
print(predict_dataset.shape)
# print(df['price'].to_list())
orig_rating = np.asarray(X['rating']).reshape(-1,1)
print(orig_rating.shape)
orig_subreg = np.asarray(X['subregion']).reshape(-1,1)
new_y = np.asarray(y[0:]).reshape(-1,1)
print(new_y.shape)

combo_df = pd.DataFrame(np.concatenate((orig_rating,orig_subreg,new_y, predict_dataset),axis=1))
combo_df = combo_df.rename(columns={0: "rating", 1: "subregion", 2: "actual_price", 3: "predicted_price"})
combo_df
# Out:
# (13688, 1)
# (13688, 1)
# (13688, 1)
#       rating      subregion actual_price predicted_price
# 0         94         Sonoma           50         53.6127
# 1         94    Napa-Sonoma           60         47.2493
# 2         94         Sonoma           65         53.6127
# 3         95         Sonoma           58         60.0696
# 4         95    Napa-Sonoma          125         61.2889
# ...      ...            ...          ...             ...
# 13683     90  Central Coast           44         27.8975
# 13684     91  Central Coast           25         33.1597
# 13685     92  Central Coast           30         35.9575
# 13686     92  Central Coast           29         35.9575
# 13687     82  Central Coast           19         17.7985
#
# [13688 rows x 4 columns]

# %%
# Save to CSV
combo_df.to_csv("Chards_Actual_Preds_subregion.csv", index=False)

# %%
# Inverse_transform list of possible rate / region combos
prediction_list = ohe.inverse_transform(predict_X_ohe)
prediction_list
# Out:
# array([[80, 'Alsace'],
#        [80, 'Arbois'],
#        [80, 'Ardèche'],
#        ...,
#        [99, 'Western Connecticut Highlands'],
#        [99, 'Willamette Valley'],
#        [99, 'Yadkin Valley']], dtype=object)

# %%
# Use model to make price predictions from list of possible rate / region combos
predicted_prices = model.predict(predict_X_ohe)
predicted_prices
# Out:
# array([[ 18.524351],
#        [ 18.344316],
#        [ 21.407759],
#        ...,
#        [282.6015  ],
#        [149.25542 ],
#        [274.13635 ]], dtype=float32)

# %%
# Concat predicted prices with associated predicted rating and subregion from original prediction list
predicted_df = pd.DataFrame(np.concatenate((prediction_list, predicted_prices), axis=1))
predicted_df = predicted_df.rename(columns={0: "rating", 1: "subregion", 2: "predicted_"})
predicted_df
# Out:
#      rating                      subregion predicted_
# 0        80                         Alsace    18.5244
# 1        80                         Arbois    18.3443
# 2        80                        Ardèche    21.4078
# 3        80                        Arizona    25.8132
# 4        80                 Auxey-Duresses    28.8086
# ...     ...                            ...        ...
# 3075     99                        Vougeot    374.698
# 3076     99               Washington Other    138.647
# 3077     99  Western Connecticut Highlands    282.602
# 3078     99              Willamette Valley    149.255
# 3079     99                  Yadkin Valley    274.136
#
# [3080 rows x 3 columns]

# %%
# Save to CSV
predicted_df.to_csv("Chards_Predictions_subregion.csv", index=False)
