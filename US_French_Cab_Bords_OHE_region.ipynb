# %%
import pandas as pd
import pandas
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import itertools
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
import sqlalchemy as sa
# Out:
# Using TensorFlow backend.

# %%
# Connect to SQL database in Postgres
wine_db = "postgresql://postgres:postgres@localhost:5432/Final"
engine = sa.create_engine(wine_db, echo=False)
conn = engine.connect()

# %%
# Select table and create df
df = pd.read_sql("SELECT * FROM us_french_cab_bords", conn)

# %%
df['subregion'] = df['subregion'].astype(str)

# %%
df
# Out:
#        index      ID  alcohol category country  \
# 0          0       1     13.2      Red      US
# 1          1      52     14.2      Red      US
# 2          2     128     14.5      Red      US
# 3          3     136     14.5      Red      US
# 4          4     161     14.7      Red      US
# ...      ...     ...      ...      ...     ...
# 18051  18050  237901     12.0      Red  France
# 18052  18051  237904     14.6      Red      US
# 18053  18052  237909     13.0      Red  France
# 18054  18053  237910     13.8      Red      US
# 18055  18055  225077     13.5      Red      US
#
#                                              description  \
# 0      This is among winemaker Cathy Corison's finest...
# 1      This bottling by industry veterans John and He...
# 2      Inky in the glass, this rich and structured bo...
# 3      This wine is pretty, floral and compact in red...
# 4      The producer's new Nomad collection includes b...
# ...                                                  ...
# 18051  A lean, rather attenuated wine. It has some pl...
# 18052  Hard to explain why the winery is only now rel...
# 18053  A raw-edged wine, with dusty tannins and black...
# 18054  The blazing vintage took its toll on this high...
# 18055  A little harsh and green, with mint, black cur...
#
#                                       designation  price price_bin  rating  \
# 0                                 Kronos Vineyard  185.0     $100+      95
# 1                                            None   35.0   $25-$50      94
# 2                                         Reserve   56.0  $51-$100      94
# 3                                            None  102.0     $100+      95
# 4      Nomad Beckstoffer Missouri Hopper Vineyard  175.0     $100+      95
# ...                                           ...    ...       ...     ...
# 18051                                        None   10.0    $0-$25      81
# 18052                                        None   28.0   $25-$50      82
# 18053                                Mouton Cadet    9.0    $0-$25      82
# 18054                                        None   42.0   $25-$50      82
# 18055                                  Seven Oaks   17.0    $0-$25      85
#
#       rating_bin      region         subregion          subsubregion  \
# 0         95-100  California              Napa            St. Helena
# 1          90-94  California     Central Coast           Paso Robles
# 2          90-94  California     Central Coast           Paso Robles
# 3         95-100  California              Napa           Napa Valley
# 4         95-100  California              Napa           Napa Valley
# ...          ...         ...               ...                   ...
# 18051      80-84    Bordeaux          Bordeaux                  None
# 18052      80-84  California     Central Coast  Santa Barbara County
# 18053      80-84    Bordeaux          Bordeaux                  None
# 18054      80-84  California  Sierra Foothills      Sierra Foothills
# 18055      85-89  California     Central Coast           Paso Robles
#
#                                                    title  \
# 0      Corison 2015 Kronos Vineyard Cabernet Sauvigno...
# 1          Falcone 2016 Cabernet Sauvignon (Paso Robles)
# 2      Daou 2016 Reserve Cabernet Sauvignon (Paso Rob...
# 3      Alpha Omega 2015 Cabernet Sauvignon (Napa Valley)
# 4      Stewart 2016 Nomad Beckstoffer Missouri Hopper...
# ...                                                  ...
# 18051                        Caves Fleury 2005  Bordeaux
# 18052  Tin House 2003 Cabernet Sauvignon (Santa Barba...
# 18053  Baron Philippe de Rothschild 2005 Mouton Cadet...
# 18054  Peters Family 2004 Cabernet Sauvignon (Sierra ...
# 18055  J. Lohr 2006 Seven Oaks Cabernet Sauvignon (Pa...
#
#                                                      url  \
# 0      https://www.winemag.com/buying-guide/corison-2...
# 1      https://www.winemag.com/buying-guide/falcone-2...
# 2      https://www.winemag.com/buying-guide/daou-2016...
# 3      https://www.winemag.com/buying-guide/alpha-ome...
# 4      https://www.winemag.com/buying-guide/stewart-2...
# ...                                                  ...
# 18051  https://www.winemag.com/buying-guide/caves-fle...
# 18052  https://www.winemag.com/buying-guide/tin-house...
# 18053  https://www.winemag.com/buying-guide/baron-phi...
# 18054  https://www.winemag.com/buying-guide/peters-fa...
# 18055  https://www.winemag.com/buying-guide/j-lohr-20...
#
#                        varietal  vintage                        winery
# 0            Cabernet Sauvignon     2015                       Corison
# 1            Cabernet Sauvignon     2016                       Falcone
# 2            Cabernet Sauvignon     2016                          Daou
# 3            Cabernet Sauvignon     2015                   Alpha Omega
# 4            Cabernet Sauvignon     2016                       Stewart
# ...                         ...      ...                           ...
# 18051  Bordeaux-style Red Blend     2005                  Caves Fleury
# 18052        Cabernet Sauvignon     2003                     Tin House
# 18053  Bordeaux-style Red Blend     2005  Baron Philippe de Rothschild
# 18054        Cabernet Sauvignon     2004                 Peters Family
# 18055        Cabernet Sauvignon     2006                       J. Lohr
#
# [18056 rows x 19 columns]

# %%
# Drop unneccessary columns
df = df.drop(['ID', 'index','category', 'country', 'subregion', 'subsubregion','varietal', 'alcohol', 'description', 'price_bin', 'rating_bin', 'designation', 'title', 'url', 'vintage','winery'], axis=1)
df.head()
# Out:
#    price  rating      region
# 0  185.0      95  California
# 1   35.0      94  California
# 2   56.0      94  California
# 3  102.0      95  California
# 4  175.0      95  California

# %%
# Drop NAs
df = df.dropna(subset=['region'])

# %%
X = df.drop("price", axis=1)
y = df["price"]

# %%
# instantiate labelencoder object
le = LabelEncoder()

# %%
# Gather lists of categories
encoded_rating = le.fit(df.rating)
rating_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
rating_name_array = le.classes_
rating_le_array = le.transform(le.classes_)

encoded_region = le.fit(df.region)
region_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
region_name_array = le.classes_
region_le_array = le.transform(le.classes_)

# Create dataframe of all possible iterations of rating and subregion pairings
predict_list = list(itertools.product(rating_name_array, region_name_array))
predict_df = pd.DataFrame(predict_list)
predict_df
# Out:
#        0                 1
# 0     80           America
# 1     80          Bordeaux
# 2     80        California
# 3     80          Colorado
# 4     80      France Other
# ..   ...               ...
# 457  100          Provence
# 458  100  Southwest France
# 459  100             Texas
# 460  100          Virginia
# 461  100        Washington
#
# [462 rows x 2 columns]

# %%
# instantiate OneHotEncoder
ohe = OneHotEncoder(sparse=False,categories="auto" )

# %%
# apply OneHotEncoder on categorical feature columns
X_ohe = ohe.fit_transform(X)

# Capture categories in variable
categories = ohe.categories_

# %%
# apply OneHotEncoder to predict_df
predict_X_ohe = ohe.fit_transform(predict_df)
# print(predict_X_ohe)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_ohe, y, random_state=42)
print(y_test.shape)
print(X_test.shape)
print(X_train.shape)
# Out:
# (4514,)
# (4514, 43)
# (13542, 43)

# %%
# Capture # inputs in a variable
input_dims = X_ohe.shape[1]
input_dims
# Out:
# 43

# %%
# Build Sequential Keras model to train and test data
model = Sequential()

model.add(Dense(128, activation = 'relu', name='dense_1', kernel_initializer='glorot_uniform', input_dim=(input_dims)))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu', name='dense_2', kernel_initializer='glorot_uniform'))
# model.add(Dropout(0.1))
# model.add(Dense(64, activation='relu', name='dense_3', kernel_initializer='glorot_uniform'))
model.add(Dense(1,name='predictions'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               5632
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# predictions (Dense)          (None, 1)                 65
# =================================================================
# Total params: 13,953
# Trainable params: 13,953
# Non-trainable params: 0
# _________________________________________________________________

# %%
from numpy import sqrt,asarray
model.compile(optimizer='adam', loss='mse', metrics=['mse','mae','mean_absolute_percentage_error'])

# %%
# from keras.callbacks import EarlyStopping

# %%
# Fit model with training data

# history = model.fit(X_train, y_train, epochs=30, callbacks=[EarlyStopping(patience=5)])
history = model.fit(X_train, y_train, epochs=40, batch_size=5,  verbose=1, validation_split=0.3)
# Out:
# Train on 9479 samples, validate on 4063 samples
# Epoch 1/40
# 9479/9479 [==============================] - 7s 707us/step - loss: 7390.4769 - mse: 7390.4663 - mae: 26.0169 - mean_absolute_percentage_error: 64.8025 - val_loss: 11275.6449 - val_mse: 11275.6494 - val_mae: 23.7738 - val_mean_absolute_percentage_error: 57.9367
# Epoch 2/40
# 9479/9479 [==============================] - 5s 497us/step - loss: 6947.2354 - mse: 6947.2363 - mae: 23.9975 - mean_absolute_percentage_error: 58.9527 - val_loss: 11077.0768 - val_mse: 11077.0674 - val_mae: 24.7384 - val_mean_absolute_percentage_error: 60.8007
# Epoch 3/40
# 9479/9479 [==============================] - 5s 509us/step - loss: 6869.9873 - mse: 6869.9937 - mae: 23.9913 - mean_absolute_percentage_error: 59.2814 - val_loss: 10904.7178 - val_mse: 10904.7197 - val_mae: 24.0077 - val_mean_absolute_percentage_error: 59.6124
# Epoch 4/40
# 9479/9479 [==============================] - 5s 515us/step - loss: 6778.7268 - mse: 6778.7246 - mae: 24.0859 - mean_absolute_percentage_error: 59.2026 - val_loss: 10741.5502 - val_mse: 10741.5430 - val_mae: 22.8482 - val_mean_absolute_percentage_error: 53.2260
# Epoch 5/40
# 9479/9479 [==============================] - 5s 506us/step - loss: 6723.1233 - mse: 6723.1265 - mae: 23.7399 - mean_absolute_percentage_error: 57.9831 - val_loss: 10534.8113 - val_mse: 10534.8154 - val_mae: 22.7063 - val_mean_absolute_percentage_error: 52.0434
# Epoch 6/40
# 9479/9479 [==============================] - 5s 496us/step - loss: 6667.0291 - mse: 6667.0288 - mae: 23.3520 - mean_absolute_percentage_error: 56.3019 - val_loss: 10320.0896 - val_mse: 10320.0908 - val_mae: 25.1188 - val_mean_absolute_percentage_error: 66.6663
# Epoch 7/40
# 9479/9479 [==============================] - 5s 504us/step - loss: 6597.5534 - mse: 6597.5571 - mae: 23.9057 - mean_absolute_percentage_error: 58.7836 - val_loss: 10182.6832 - val_mse: 10182.6719 - val_mae: 22.6003 - val_mean_absolute_percentage_error: 50.9700
# Epoch 8/40
# 9479/9479 [==============================] - 5s 499us/step - loss: 6521.2432 - mse: 6521.2466 - mae: 23.8488 - mean_absolute_percentage_error: 58.2965 - val_loss: 9912.7939 - val_mse: 9912.8086 - val_mae: 22.7600 - val_mean_absolute_percentage_error: 52.0044
# Epoch 9/40
# 9479/9479 [==============================] - 5s 500us/step - loss: 6483.2933 - mse: 6483.2969 - mae: 23.5348 - mean_absolute_percentage_error: 57.0121 - val_loss: 9676.4885 - val_mse: 9676.4814 - val_mae: 24.1206 - val_mean_absolute_percentage_error: 59.7622
# Epoch 10/40
# 9479/9479 [==============================] - 5s 517us/step - loss: 6421.6401 - mse: 6421.6392 - mae: 23.3978 - mean_absolute_percentage_error: 56.0578 - val_loss: 9560.5191 - val_mse: 9560.5186 - val_mae: 24.1083 - val_mean_absolute_percentage_error: 61.2959
# Epoch 11/40
# 9479/9479 [==============================] - 5s 531us/step - loss: 6364.8226 - mse: 6364.8247 - mae: 23.6593 - mean_absolute_percentage_error: 57.6315 - val_loss: 9346.0946 - val_mse: 9346.1006 - val_mae: 23.0873 - val_mean_absolute_percentage_error: 55.3656
# Epoch 12/40
# 9479/9479 [==============================] - 5s 481us/step - loss: 6369.0413 - mse: 6369.0488 - mae: 23.4267 - mean_absolute_percentage_error: 56.0933 - val_loss: 9254.0193 - val_mse: 9254.0273 - val_mae: 24.6724 - val_mean_absolute_percentage_error: 65.8503
# Epoch 13/40
# 9479/9479 [==============================] - 5s 516us/step - loss: 6350.1817 - mse: 6350.1841 - mae: 23.7533 - mean_absolute_percentage_error: 57.9427 - val_loss: 9110.6627 - val_mse: 9110.6582 - val_mae: 22.3622 - val_mean_absolute_percentage_error: 50.5720
# Epoch 14/40
# 9479/9479 [==============================] - 5s 532us/step - loss: 6296.3409 - mse: 6296.3403 - mae: 23.5107 - mean_absolute_percentage_error: 57.0611 - val_loss: 9153.1931 - val_mse: 9153.2021 - val_mae: 22.6145 - val_mean_absolute_percentage_error: 53.1311
# Epoch 15/40
# 9479/9479 [==============================] - 5s 507us/step - loss: 6331.4839 - mse: 6331.4878 - mae: 23.5241 - mean_absolute_percentage_error: 57.0573 - val_loss: 8942.0924 - val_mse: 8942.0928 - val_mae: 23.5396 - val_mean_absolute_percentage_error: 57.4456
# Epoch 16/40
# 9479/9479 [==============================] - 5s 507us/step - loss: 6312.9393 - mse: 6312.9443 - mae: 23.6192 - mean_absolute_percentage_error: 57.2117 - val_loss: 8941.5879 - val_mse: 8941.5889 - val_mae: 23.3568 - val_mean_absolute_percentage_error: 57.9850
# Epoch 17/40
# 9479/9479 [==============================] - 5s 515us/step - loss: 6307.8257 - mse: 6307.8223 - mae: 23.3938 - mean_absolute_percentage_error: 56.0607 - val_loss: 8784.5046 - val_mse: 8784.5020 - val_mae: 23.2694 - val_mean_absolute_percentage_error: 57.2961
# Epoch 18/40
# 9479/9479 [==============================] - 5s 539us/step - loss: 6280.1782 - mse: 6280.1724 - mae: 23.3870 - mean_absolute_percentage_error: 56.4369 - val_loss: 8680.3962 - val_mse: 8680.3984 - val_mae: 23.4919 - val_mean_absolute_percentage_error: 57.3723
# Epoch 19/40
# %%
# Evaluate error and print MSE, MAE and Mean Absolute Percentage Error
error = model.evaluate(X_test, y_test, verbose=2)

print(f"MSE: {error[0]}")
print(f"MAE: {error[1]}")
print(f"Mean Absolute Percentage Error: {error[2]}")
# Out:
# MSE: 1194.88785848757
# MAE: 1194.887451171875
# Mean Absolute Percentage Error: 20.506994247436523

# %%
# Build plot of training loss and validation loss

# print(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Compare one sample y with a predicted y
test_data = X_test[0]
pred = (model.predict(test_data.reshape(1,43)))
print(f"Predicted Price: {pred}")
print(f"Predicted Rating and Region {ohe.inverse_transform(X_test[0].reshape(1,-1))}")
print('---------------------------------------------------------------------------')
print(f"Actual Price: {y[0]}")
print(f"Actual Rating: {X.rating[1]}")
print(f"Actual Region: {X.region[1]}")
# Out:
# Predicted Price: [[27.467854]]
# Predicted Rating and Region [[88 'Bordeaux']]
# ---------------------------------------------------------------------------
# Actual Price: 185.0
# Actual Rating: 94
# Actual Region: California

# %%
# Save model
# model.save('model_us_french_Cab_Bords_OHE_region.h5')

# %%
# Load old model for testing

from tensorflow.keras.models import load_model
# old_model = load_model('model_us_french_Cab_Bords_OHE_region.h5')

# %%
# Use to compare predicted price to predicted price of old model

# print(y[0])
# test_data = X_test[0]
# pred = (old_model.predict(test_data.reshape(1,174)))
# print(pred)

# %%
# Show one X value from OHE version of list of possible rate / region combos
test = np.expand_dims(X_ohe[0], axis=0)

# %%
# Make predictions on original dataset
predict_dataset = model.predict(X_ohe)
predict_dataset
print(predict_dataset.shape)
# Out:
# (18056, 1)

# %%
# Add predicted price to dataframe
df["predicted price"] = predict_dataset
df= combo_df
combo_df
# Out:
#       rating      region actual_price predicted_price
# 0         95  California          185         111.642
# 1         94  California           35         98.7105
# 2         94  California           56         98.7105
# 3         95  California          102         111.642
# 4         95  California          175         111.642
# ...      ...         ...          ...             ...
# 18051     81    Bordeaux           10         11.5115
# 18052     82  California           28         25.8671
# 18053     82    Bordeaux            9         17.5083
# 18054     82  California           42         25.8671
# 18055     85  California           17         31.9162
#
# [18056 rows x 4 columns]

# %%
combo_df.to_csv("Cab_Bords_Actual_Pred_region.csv", index=False)

# %%
# Inverse_transform list of possible rate / region combos
prediction_list = ohe.inverse_transform(predict_X_ohe)
prediction_list
# Out:
# array([[80, 'America'],
#        [80, 'Bordeaux'],
#        [80, 'California'],
#        [80, 'Colorado'],
#        [80, 'France Other'],
#        [80, 'Idaho'],
#        [80, 'Languedoc-Roussillon'],
#        [80, 'Loire Valley'],
#        [80, 'Michigan'],
#        [80, 'Missouri'],
#        [80, 'New Jersey'],
#        [80, 'New Mexico'],
#        [80, 'New York'],
#        [80, 'North Carolina'],
#        [80, 'Ohio'],
#        [80, 'Oregon'],
#        [80, 'Pennsylvania'],
#        [80, 'Provence'],
#        [80, 'Southwest France'],
#        [80, 'Texas'],
#        [80, 'Virginia'],
#        [80, 'Washington'],
#        [81, 'America'],
#        [81, 'Bordeaux'],
#        [81, 'California'],
#        [81, 'Colorado'],
#        [81, 'France Other'],
#        [81, 'Idaho'],
#        [81, 'Languedoc-Roussillon'],
#        [81, 'Loire Valley'],
#        [81, 'Michigan'],
#        [81, 'Missouri'],
#        [81, 'New Jersey'],
#        [81, 'New Mexico'],
#        [81, 'New York'],
#        [81, 'North Carolina'],
#        [81, 'Ohio'],
#        [81, 'Oregon'],
#        [81, 'Pennsylvania'],
#        [81, 'Provence'],
#        [81, 'Southwest France'],
#        [81, 'Texas'],
#        [81, 'Virginia'],
#        [81, 'Washington'],
#        [82, 'America'],
#        [82, 'Bordeaux'],
#        [82, 'California'],
#        [82, 'Colorado'],
#        [82, 'France Other'],
#        [82, 'Idaho'],
#        [82, 'Languedoc-Roussillon'],
#        [82, 'Loire Valley'],
#        [82, 'Michigan'],
#        [82, 'Missouri'],
#        [82, 'New Jersey'],
#        [82, 'New Mexico'],
#        [82, 'New York'],
#        [82, 'North Carolina'],
#        [82, 'Ohio'],
#        [82, 'Oregon'],
#        [82, 'Pennsylvania'],
#        [82, 'Provence'],
#        [82, 'Southwest France'],
#        [82, 'Texas'],
#        [82, 'Virginia'],
#        [82, 'Washington'],
#        [83, 'America'],
#        [83, 'Bordeaux'],
#        [83, 'California'],
#        [83, 'Colorado'],
#        [83, 'France Other'],
#        [83, 'Idaho'],
#        [83, 'Languedoc-Roussillon'],
#        [83, 'Loire Valley'],
#        [83, 'Michigan'],
#        [83, 'Missouri'],
#        [83, 'New Jersey'],
#        [83, 'New Mexico'],
#        [83, 'New York'],
#        [83, 'North Carolina'],
#        [83, 'Ohio'],
#        [83, 'Oregon'],
#        [83, 'Pennsylvania'],
#        [83, 'Provence'],
#        [83, 'Southwest France'],
#        [83, 'Texas'],
#        [83, 'Virginia'],
#        [83, 'Washington'],
#        [84, 'America'],
#        [84, 'Bordeaux'],
#        [84, 'California'],
#        [84, 'Colorado'],
#        [84, 'France Other'],
#        [84, 'Idaho'],
#        [84, 'Languedoc-Roussillon'],
#        [84, 'Loire Valley'],
#        [84, 'Michigan'],
#        [84, 'Missouri'],
#        [84, 'New Jersey'],
#        [84, 'New Mexico'],
#        [84, 'New York'],
#        [84, 'North Carolina'],
#        [84, 'Ohio'],
#        [84, 'Oregon'],
#        [84, 'Pennsylvania'],
#        [84, 'Provence'],
#        [84, 'Southwest France'],
#        [84, 'Texas'],
#        [84, 'Virginia'],
#        [84, 'Washington'],
#        [85, 'America'],
#        [85, 'Bordeaux'],
#        [85, 'California'],
#        [85, 'Colorado'],
#        [85, 'France Other'],
#        [85, 'Idaho'],
#        [85, 'Languedoc-Roussillon'],
#        [85, 'Loire Valley'],
#        [85, 'Michigan'],
#        [85, 'Missouri'],
#        [85, 'New Jersey'],
#        [85, 'New Mexico'],
#        [85, 'New York'],
#        [85, 'North Carolina'],
#        [85, 'Ohio'],
#        [85, 'Oregon'],
#        [85, 'Pennsylvania'],
#        [85, 'Provence'],
#        [85, 'Southwest France'],
#        [85, 'Texas'],
#        [85, 'Virginia'],
#        [85, 'Washington'],
#        [86, 'America'],
#        [86, 'Bordeaux'],
#        [86, 'California'],
#        [86, 'Colorado'],
#        [86, 'France Other'],
#        [86, 'Idaho'],
#        [86, 'Languedoc-Roussillon'],
#        [86, 'Loire Valley'],
#        [86, 'Michigan'],
#        [86, 'Missouri'],
#        [86, 'New Jersey'],
#        [86, 'New Mexico'],
#        [86, 'New York'],
#        [86, 'North Carolina'],
#        [86, 'Ohio'],
#        [86, 'Oregon'],
#        [86, 'Pennsylvania'],
#        [86, 'Provence'],
#        [86, 'Southwest France'],
#        [86, 'Texas'],
#        [86, 'Virginia'],
#        [86, 'Washington'],
#        [87, 'America'],
#        [87, 'Bordeaux'],
#        [87, 'California'],
#        [87, 'Colorado'],
#        [87, 'France Other'],
#        [87, 'Idaho'],
#        [87, 'Languedoc-Roussillon'],
#        [87, 'Loire Valley'],
#        [87, 'Michigan'],
#        [87, 'Missouri'],
#        [87, 'New Jersey'],
#        [87, 'New Mexico'],
#        [87, 'New York'],
#        [87, 'North Carolina'],
#        [87, 'Ohio'],
#        [87, 'Oregon'],
#        [87, 'Pennsylvania'],
#        [87, 'Provence'],
#        [87, 'Southwest France'],
#        [87, 'Texas'],
#        [87, 'Virginia'],
#        [87, 'Washington'],
#        [88, 'America'],
#        [88, 'Bordeaux'],
#        [88, 'California'],
#        [88, 'Colorado'],
#        [88, 'France Other'],
#        [88, 'Idaho'],
#        [88, 'Languedoc-Roussillon'],
#        [88, 'Loire Valley'],
#        [88, 'Michigan'],
#        [88, 'Missouri'],
#        [88, 'New Jersey'],
#        [88, 'New Mexico'],
#        [88, 'New York'],
#        [88, 'North Carolina'],
#        [88, 'Ohio'],
#        [88, 'Oregon'],
#        [88, 'Pennsylvania'],
#        [88, 'Provence'],
#        [88, 'Southwest France'],
#        [88, 'Texas'],
#        [88, 'Virginia'],
#        [88, 'Washington'],
#        [89, 'America'],
#        [89, 'Bordeaux'],
#        [89, 'California'],
#        [89, 'Colorado'],
#        [89, 'France Other'],
#        [89, 'Idaho'],
#        [89, 'Languedoc-Roussillon'],
#        [89, 'Loire Valley'],
#        [89, 'Michigan'],
#        [89, 'Missouri'],
#        [89, 'New Jersey'],
#        [89, 'New Mexico'],
#        [89, 'New York'],
#        [89, 'North Carolina'],
#        [89, 'Ohio'],
#        [89, 'Oregon'],
#        [89, 'Pennsylvania'],
#        [89, 'Provence'],
#        [89, 'Southwest France'],
#        [89, 'Texas'],
#        [89, 'Virginia'],
#        [89, 'Washington'],
#        [90, 'America'],
#        [90, 'Bordeaux'],
#        [90, 'California'],
#        [90, 'Colorado'],
#        [90, 'France Other'],
#        [90, 'Idaho'],
#        [90, 'Languedoc-Roussillon'],
#        [90, 'Loire Valley'],
#        [90, 'Michigan'],
#        [90, 'Missouri'],
#        [90, 'New Jersey'],
#        [90, 'New Mexico'],
#        [90, 'New York'],
#        [90, 'North Carolina'],
#        [90, 'Ohio'],
#        [90, 'Oregon'],
#        [90, 'Pennsylvania'],
#        [90, 'Provence'],
#        [90, 'Southwest France'],
#        [90, 'Texas'],
#        [90, 'Virginia'],
#        [90, 'Washington'],
#        [91, 'America'],
#        [91, 'Bordeaux'],
#        [91, 'California'],
#        [91, 'Colorado'],
#        [91, 'France Other'],
#        [91, 'Idaho'],
#        [91, 'Languedoc-Roussillon'],
#        [91, 'Loire Valley'],
#        [91, 'Michigan'],
#        [91, 'Missouri'],
#        [91, 'New Jersey'],
#        [91, 'New Mexico'],
#        [91, 'New York'],
#        [91, 'North Carolina'],
#        [91, 'Ohio'],
#        [91, 'Oregon'],
#        [91, 'Pennsylvania'],
#        [91, 'Provence'],
#        [91, 'Southwest France'],
#        [91, 'Texas'],
#        [91, 'Virginia'],
#        [91, 'Washington'],
#        [92, 'America'],
#        [92, 'Bordeaux'],
#        [92, 'California'],
#        [92, 'Colorado'],
#        [92, 'France Other'],
#        [92, 'Idaho'],
#        [92, 'Languedoc-Roussillon'],
#        [92, 'Loire Valley'],
#        [92, 'Michigan'],
#        [92, 'Missouri'],
#        [92, 'New Jersey'],
#        [92, 'New Mexico'],
#        [92, 'New York'],
#        [92, 'North Carolina'],
#        [92, 'Ohio'],
#        [92, 'Oregon'],
#        [92, 'Pennsylvania'],
#        [92, 'Provence'],
#        [92, 'Southwest France'],
#        [92, 'Texas'],
#        [92, 'Virginia'],
#        [92, 'Washington'],
#        [93, 'America'],
#        [93, 'Bordeaux'],
#        [93, 'California'],
#        [93, 'Colorado'],
#        [93, 'France Other'],
#        [93, 'Idaho'],
#        [93, 'Languedoc-Roussillon'],
#        [93, 'Loire Valley'],
#        [93, 'Michigan'],
#        [93, 'Missouri'],
#        [93, 'New Jersey'],
#        [93, 'New Mexico'],
#        [93, 'New York'],
#        [93, 'North Carolina'],
#        [93, 'Ohio'],
#        [93, 'Oregon'],
#        [93, 'Pennsylvania'],
#        [93, 'Provence'],
#        [93, 'Southwest France'],
#        [93, 'Texas'],
#        [93, 'Virginia'],
#        [93, 'Washington'],
#        [94, 'America'],
#        [94, 'Bordeaux'],
#        [94, 'California'],
#        [94, 'Colorado'],
#        [94, 'France Other'],
#        [94, 'Idaho'],
#        [94, 'Languedoc-Roussillon'],
#        [94, 'Loire Valley'],
#        [94, 'Michigan'],
#        [94, 'Missouri'],
#        [94, 'New Jersey'],
#        [94, 'New Mexico'],
#        [94, 'New York'],
#        [94, 'North Carolina'],
#        [94, 'Ohio'],
#        [94, 'Oregon'],
#        [94, 'Pennsylvania'],
#        [94, 'Provence'],
#        [94, 'Southwest France'],
#        [94, 'Texas'],
#        [94, 'Virginia'],
#        [94, 'Washington'],
#        [95, 'America'],
#        [95, 'Bordeaux'],
#        [95, 'California'],
#        [95, 'Colorado'],
#        [95, 'France Other'],
#        [95, 'Idaho'],
#        [95, 'Languedoc-Roussillon'],
#        [95, 'Loire Valley'],
#        [95, 'Michigan'],
#        [95, 'Missouri'],
#        [95, 'New Jersey'],
#        [95, 'New Mexico'],
#        [95, 'New York'],
#        [95, 'North Carolina'],
#        [95, 'Ohio'],
#        [95, 'Oregon'],
#        [95, 'Pennsylvania'],
#        [95, 'Provence'],
#        [95, 'Southwest France'],
#        [95, 'Texas'],
#        [95, 'Virginia'],
#        [95, 'Washington'],
#        [96, 'America'],
#        [96, 'Bordeaux'],
#        [96, 'California'],
#        [96, 'Colorado'],
#        [96, 'France Other'],
#        [96, 'Idaho'],
#        [96, 'Languedoc-Roussillon'],
#        [96, 'Loire Valley'],
#        [96, 'Michigan'],
#        [96, 'Missouri'],
#        [96, 'New Jersey'],
#        [96, 'New Mexico'],
#        [96, 'New York'],
#        [96, 'North Carolina'],
#        [96, 'Ohio'],
#        [96, 'Oregon'],
#        [96, 'Pennsylvania'],
#        [96, 'Provence'],
#        [96, 'Southwest France'],
#        [96, 'Texas'],
#        [96, 'Virginia'],
#        [96, 'Washington'],
#        [97, 'America'],
#        [97, 'Bordeaux'],
#        [97, 'California'],
#        [97, 'Colorado'],
#        [97, 'France Other'],
#        [97, 'Idaho'],
#        [97, 'Languedoc-Roussillon'],
#        [97, 'Loire Valley'],
#        [97, 'Michigan'],
#        [97, 'Missouri'],
#        [97, 'New Jersey'],
#        [97, 'New Mexico'],
#        [97, 'New York'],
#        [97, 'North Carolina'],
#        [97, 'Ohio'],
#        [97, 'Oregon'],
#        [97, 'Pennsylvania'],
#        [97, 'Provence'],
#        [97, 'Southwest France'],
#        [97, 'Texas'],
#        [97, 'Virginia'],
#        [97, 'Washington'],
#        [98, 'America'],
#        [98, 'Bordeaux'],
#        [98, 'California'],
#        [98, 'Colorado'],
#        [98, 'France Other'],
#        [98, 'Idaho'],
#        [98, 'Languedoc-Roussillon'],
#        [98, 'Loire Valley'],
#        [98, 'Michigan'],
#        [98, 'Missouri'],
#        [98, 'New Jersey'],
#        [98, 'New Mexico'],
#        [98, 'New York'],
#        [98, 'North Carolina'],
#        [98, 'Ohio'],
#        [98, 'Oregon'],
#        [98, 'Pennsylvania'],
#        [98, 'Provence'],
#        [98, 'Southwest France'],
#        [98, 'Texas'],
#        [98, 'Virginia'],
#        [98, 'Washington'],
#        [99, 'America'],
#        [99, 'Bordeaux'],
#        [99, 'California'],
#        [99, 'Colorado'],
#        [99, 'France Other'],
#        [99, 'Idaho'],
#        [99, 'Languedoc-Roussillon'],
#        [99, 'Loire Valley'],
#        [99, 'Michigan'],
#        [99, 'Missouri'],
#        [99, 'New Jersey'],
#        [99, 'New Mexico'],
#        [99, 'New York'],
#        [99, 'North Carolina'],
#        [99, 'Ohio'],
#        [99, 'Oregon'],
#        [99, 'Pennsylvania'],
#        [99, 'Provence'],
#        [99, 'Southwest France'],
#        [99, 'Texas'],
#        [99, 'Virginia'],
#        [99, 'Washington'],
#        [100, 'America'],
#        [100, 'Bordeaux'],
#        [100, 'California'],
#        [100, 'Colorado'],
#        [100, 'France Other'],
#        [100, 'Idaho'],
#        [100, 'Languedoc-Roussillon'],
#        [100, 'Loire Valley'],
#        [100, 'Michigan'],
#        [100, 'Missouri'],
#        [100, 'New Jersey'],
#        [100, 'New Mexico'],
#        [100, 'New York'],
#        [100, 'North Carolina'],
#        [100, 'Ohio'],
#        [100, 'Oregon'],
#        [100, 'Pennsylvania'],
#        [100, 'Provence'],
#        [100, 'Southwest France'],
#        [100, 'Texas'],
#        [100, 'Virginia'],
#        [100, 'Washington']], dtype=object)

# %%
# Use model to make price predictions from list of possible rate / region combos
predicted_prices = model.predict(predict_X_ohe)
predicted_prices
# Out:
# array([[  13.91975  ],
#        [  13.408097 ],
#        [  22.674675 ],
#        [  20.152348 ],
#        [  13.724748 ],
#        [  14.93806  ],
#        [  11.2950945],
#        [  12.060393 ],
#        [  47.886665 ],
#        [  28.67553  ],
#        [  17.156641 ],
#        [  16.590721 ],
#        [  18.678991 ],
#        [  19.583174 ],
#        [  18.765526 ],
#        [  30.091724 ],
#        [  14.537495 ],
#        [  11.084317 ],
#        [  20.955372 ],
#        [  15.291411 ],
#        [  19.456911 ],
#        [  18.649895 ],
#        [  14.434062 ],
#        [  11.511523 ],
#        [  20.124542 ],
#        [  17.418339 ],
#        [  12.834619 ],
#        [  14.819398 ],
#        [   7.4290285],
#        [  11.527465 ],
#        [  20.324446 ],
#        [  26.398766 ],
#        [  15.220881 ],
#        [  15.290145 ],
#        [  18.413994 ],
#        [  16.505774 ],
#        [  17.250666 ],
#        [  30.460106 ],
#        [  26.947947 ],
#        [  11.868853 ],
#        [  18.037968 ],
#        [  16.300838 ],
#        [  19.41175  ],
#        [  19.858318 ],
#        [  15.278844 ],
#        [  17.50834  ],
#        [  25.867077 ],
#        [  24.969534 ],
#        [  13.782569 ],
#        [  22.39051  ],
#        [   8.797089 ],
#        [  15.804126 ],
#        [  60.014885 ],
#        [  39.911163 ],
#        [  29.139622 ],
#        [  26.8922   ],
#        [  34.591278 ],
#        [  25.670147 ],
#        [  29.014385 ],
#        [  45.69911  ],
#        [  36.264565 ],
#        [  13.330644 ],
#        [  23.6857   ],
#        [  23.899511 ],
#        [  26.372372 ],
#        [  23.760849 ],
#        [  20.234901 ],
#        [  16.128471 ],
#        [  25.874882 ],
#        [  24.329514 ],
#        [  12.987403 ],
#        [  20.548275 ],
#        [   9.633922 ],
#        [  16.082413 ],
#        [  52.076385 ],
#        [  31.27164  ],
#        [  20.482567 ],
#        [  15.853927 ],
#        [  19.133976 ],
#        [  17.024817 ],
#        [  23.609627 ],
#        [  38.43187  ],
#        [  29.33191  ],
#        [  15.355414 ],
#        [  22.342354 ],
#        [  22.170261 ],
#        [  26.18107  ],
#        [  21.009312 ],
#        [  21.309116 ],
#        [  18.793274 ],
#        [  31.540733 ],
#        [  23.696255 ],
#        [  13.558461 ],
#        [  25.169092 ],
#        [  14.37273  ],
#        [  17.200943 ],
#        [  55.91896  ],
#        [  30.388166 ],
#        [  26.060867 ],
#        [  23.08626  ],
#        [  30.48995  ],
#        [  28.185041 ],
#        [  30.633759 ],
#        [  27.318415 ],
#        [  35.17424  ],
#        [  17.158604 ],
#        [  37.32141  ],
#        [  20.354645 ],
#        [  24.927376 ],
#        [  21.24647  ],
#        [  14.674285 ],
#        [  17.047974 ],
#        [  31.916172 ],
#        [  16.838978 ],
#        [  13.6029005],
#        [  24.335148 ],
#        [  70.67262  ],
#        [ 144.38393  ],
#        [ 121.34813  ],
#        [  97.61847  ],
#        [ 124.85685  ],
#        [ 278.87903  ],
#        [ 173.75658  ],
#        [ 172.97836  ],
#        [ 100.5188   ],
#        [ 129.07816  ],
#        [ 125.322945 ],
#        [ 113.95743  ],
#        [ 231.43172  ],
#        [ 197.63274  ],
#        [ 170.03954  ],
#        [ 177.22826  ],
#        [ 145.90915  ],
#        [ 183.24406  ],
#        [ 188.23474  ],
#        [  90.233444 ],
#        [ 187.16629  ],
#        [ 112.14703  ],
#        [  90.8154   ],
#        [ 163.34581  ],
#        [ 150.05214  ],
#        [  81.1512   ],
#        [ 147.30133  ],
#        [ 218.5919   ],
#        [ 229.54964  ],
#        [ 195.08113  ],
#        [ 135.41263  ],
#        [ 165.80609  ],
#        [ 155.32457  ],
#        [ 153.24254  ],
#        [ 266.71234  ],
#        [ 229.98514  ],
#        [ 208.3676   ],
#        [ 197.86993  ],
#        [ 171.97543  ],
#        [ 214.98875  ],
#        [ 225.31111  ],
#        [ 138.81076  ],
#        [ 227.3052   ],
#        [ 155.55411  ],
#        [ 115.77815  ],
#        [ 216.44298  ],
#        [ 186.73543  ],
#        [ 114.86832  ],
#        [ 190.11336  ],
#        [ 456.44937  ],
#        [ 140.198    ],
#        [ 287.3457   ],
#        [ 180.50575  ],
#        [ 237.17299  ],
#        [ 183.36009  ],
#        [ 192.48166  ],
#        [ 365.9904   ],
#        [ 298.5638   ],
#        [ 283.825    ],
#        [ 279.7383   ],
#        [ 220.79576  ],
#        [ 292.9944   ],
#        [ 274.11404  ],
#        [ 134.38379  ],
#        [ 300.61575  ],
#        [ 203.28343  ],
#        [ 150.41225  ],
#        [ 290.62216  ],
#        [ 235.85332  ],
#        [ 130.08072  ],
#        [ 905.59344  ],
#        [1196.8705   ],
#        [ 524.0911   ],
#        [1007.01404  ],
#        [ 892.5352   ],
#        [ 940.4498   ],
#        [ 898.6642   ],
#        [ 913.05743  ],
#        [1090.1113   ],
#        [1015.2223   ],
#        [1002.1383   ],
#        [1006.3251   ],
#        [ 919.3345   ],
#        [1015.85736  ],
#        [ 997.5442   ],
#        [ 726.63293  ],
#        [1026.7483   ],
#        [ 920.8795   ],
#        [ 826.8629   ],
#        [1013.0914   ],
#        [ 954.3777   ],
#        [ 645.8697   ]], dtype=float32)

# %%
# Concat predicted prices with associated predicted rating and subregion from original prediction list

predicted_df = pd.DataFrame(np.concatenate((prediction_list, predicted_prices), axis=1))
predicted_df = predicted_df.rename(columns={0: "rating", 1: "region", 2: "predicted_"})
predicted_df
# Out:
#     rating            region predicted_
# 0       80           America    13.9198
# 1       80          Bordeaux    13.4081
# 2       80        California    22.6747
# 3       80          Colorado    20.1523
# 4       80      France Other    13.7247
# ..     ...               ...        ...
# 457    100          Provence     920.88
# 458    100  Southwest France    826.863
# 459    100             Texas    1013.09
# 460    100          Virginia    954.378
# 461    100        Washington     645.87
#
# [462 rows x 3 columns]

# %%
predicted_df.to_csv("Cab_Bords_Predictions_region.csv", index=False)
