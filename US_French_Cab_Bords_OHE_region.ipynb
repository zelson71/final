# %%
import pandas as pd
import pandas
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import itertools
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
import sqlalchemy as sa

# %%
# Connect to SQL database in Postgres
wine_db = "postgresql://postgres:postgres@localhost:5432/Final"
engine = sa.create_engine(wine_db, echo=False)
conn = engine.connect()

# %%
# Select table and create df
df = pd.read_sql("SELECT * FROM us_french_cab_bords", conn)

# %%
df['subregion'] = df['subregion'].astype(str)

# %%
df
# Out:
#        index      ID  alcohol category country  \
# 0          0       1     13.2      Red      US
# 1          1      52     14.2      Red      US
# 2          2     128     14.5      Red      US
# 3          3     136     14.5      Red      US
# 4          4     161     14.7      Red      US
# ...      ...     ...      ...      ...     ...
# 18051  18050  237901     12.0      Red  France
# 18052  18051  237904     14.6      Red      US
# 18053  18052  237909     13.0      Red  France
# 18054  18053  237910     13.8      Red      US
# 18055  18055  225077     13.5      Red      US
#
#                                              description  \
# 0      This is among winemaker Cathy Corison's finest...
# 1      This bottling by industry veterans John and He...
# 2      Inky in the glass, this rich and structured bo...
# 3      This wine is pretty, floral and compact in red...
# 4      The producer's new Nomad collection includes b...
# ...                                                  ...
# 18051  A lean, rather attenuated wine. It has some pl...
# 18052  Hard to explain why the winery is only now rel...
# 18053  A raw-edged wine, with dusty tannins and black...
# 18054  The blazing vintage took its toll on this high...
# 18055  A little harsh and green, with mint, black cur...
#
#                                       designation  price price_bin  rating  \
# 0                                 Kronos Vineyard  185.0     $100+      95
# 1                                            None   35.0   $25-$50      94
# 2                                         Reserve   56.0  $51-$100      94
# 3                                            None  102.0     $100+      95
# 4      Nomad Beckstoffer Missouri Hopper Vineyard  175.0     $100+      95
# ...                                           ...    ...       ...     ...
# 18051                                        None   10.0    $0-$25      81
# 18052                                        None   28.0   $25-$50      82
# 18053                                Mouton Cadet    9.0    $0-$25      82
# 18054                                        None   42.0   $25-$50      82
# 18055                                  Seven Oaks   17.0    $0-$25      85
#
#       rating_bin      region         subregion          subsubregion  \
# 0         95-100  California              Napa            St. Helena
# 1          90-94  California     Central Coast           Paso Robles
# 2          90-94  California     Central Coast           Paso Robles
# 3         95-100  California              Napa           Napa Valley
# 4         95-100  California              Napa           Napa Valley
# ...          ...         ...               ...                   ...
# 18051      80-84    Bordeaux          Bordeaux                  None
# 18052      80-84  California     Central Coast  Santa Barbara County
# 18053      80-84    Bordeaux          Bordeaux                  None
# 18054      80-84  California  Sierra Foothills      Sierra Foothills
# 18055      85-89  California     Central Coast           Paso Robles
#
#                                                    title  \
# 0      Corison 2015 Kronos Vineyard Cabernet Sauvigno...
# 1          Falcone 2016 Cabernet Sauvignon (Paso Robles)
# 2      Daou 2016 Reserve Cabernet Sauvignon (Paso Rob...
# 3      Alpha Omega 2015 Cabernet Sauvignon (Napa Valley)
# 4      Stewart 2016 Nomad Beckstoffer Missouri Hopper...
# ...                                                  ...
# 18051                        Caves Fleury 2005  Bordeaux
# 18052  Tin House 2003 Cabernet Sauvignon (Santa Barba...
# 18053  Baron Philippe de Rothschild 2005 Mouton Cadet...
# 18054  Peters Family 2004 Cabernet Sauvignon (Sierra ...
# 18055  J. Lohr 2006 Seven Oaks Cabernet Sauvignon (Pa...
#
#                                                      url  \
# 0      https://www.winemag.com/buying-guide/corison-2...
# 1      https://www.winemag.com/buying-guide/falcone-2...
# 2      https://www.winemag.com/buying-guide/daou-2016...
# 3      https://www.winemag.com/buying-guide/alpha-ome...
# 4      https://www.winemag.com/buying-guide/stewart-2...
# ...                                                  ...
# 18051  https://www.winemag.com/buying-guide/caves-fle...
# 18052  https://www.winemag.com/buying-guide/tin-house...
# 18053  https://www.winemag.com/buying-guide/baron-phi...
# 18054  https://www.winemag.com/buying-guide/peters-fa...
# 18055  https://www.winemag.com/buying-guide/j-lohr-20...
#
#                        varietal  vintage                        winery
# 0            Cabernet Sauvignon     2015                       Corison
# 1            Cabernet Sauvignon     2016                       Falcone
# 2            Cabernet Sauvignon     2016                          Daou
# 3            Cabernet Sauvignon     2015                   Alpha Omega
# 4            Cabernet Sauvignon     2016                       Stewart
# ...                         ...      ...                           ...
# 18051  Bordeaux-style Red Blend     2005                  Caves Fleury
# 18052        Cabernet Sauvignon     2003                     Tin House
# 18053  Bordeaux-style Red Blend     2005  Baron Philippe de Rothschild
# 18054        Cabernet Sauvignon     2004                 Peters Family
# 18055        Cabernet Sauvignon     2006                       J. Lohr
#
# [18056 rows x 19 columns]

# %%
# Drop unneccessary columns
df = df.drop(['ID', 'index','category', 'country', 'subregion', 'subsubregion','varietal', 'alcohol', 'description', 'price_bin', 'rating_bin', 'designation', 'title', 'url', 'vintage','winery'], axis=1)
df.head()
# Out:
#    price  rating      region
# 0  185.0      95  California
# 1   35.0      94  California
# 2   56.0      94  California
# 3  102.0      95  California
# 4  175.0      95  California

# %%
# Drop NAs
df = df.dropna(subset=['region'])

# %%
X = df.drop("price", axis=1)
y = df["price"]

# %%
# instantiate labelencoder object
le = LabelEncoder()

# %%
# Gather lists of categories
encoded_rating = le.fit(df.rating)
rating_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
rating_name_array = le.classes_
rating_le_array = le.transform(le.classes_)

encoded_region = le.fit(df.region)
region_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
region_name_array = le.classes_
region_le_array = le.transform(le.classes_)

# Create dataframe of all possible iterations of rating and subregion pairings
predict_list = list(itertools.product(rating_name_array, region_name_array))
predict_df = pd.DataFrame(predict_list)
predict_df
# Out:
#        0                 1
# 0     80           America
# 1     80          Bordeaux
# 2     80        California
# 3     80          Colorado
# 4     80      France Other
# ..   ...               ...
# 457  100          Provence
# 458  100  Southwest France
# 459  100             Texas
# 460  100          Virginia
# 461  100        Washington
#
# [462 rows x 2 columns]

# %%
# instantiate OneHotEncoder
ohe = OneHotEncoder(sparse=False,categories="auto" )

# %%
# apply OneHotEncoder on categorical feature columns
X_ohe = ohe.fit_transform(X)

# Capture categories in variable
categories = ohe.categories_

# %%
# apply OneHotEncoder to predict_df
predict_X_ohe = ohe.fit_transform(predict_df)
# print(predict_X_ohe)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_ohe, y, random_state=42)
print(y_test.shape)
print(X_test.shape)
print(X_train.shape)
# Out:
# (4514,)
# (4514, 43)
# (13542, 43)

# %%
# Capture # inputs in a variable
input_dims = X_ohe.shape[1]
input_dims
# Out:
# 43

# %%
# Build Sequential Keras model to train and test data
model = Sequential()

model.add(Dense(750, activation = 'relu', name='dense_1', kernel_initializer='glorot_uniform', input_dim=(input_dims)))
model.add(Dropout(0.1))
model.add(Dense(375, activation='relu', name='dense_2', kernel_initializer='glorot_uniform'))
# model.add(Dropout(0.1))
# model.add(Dense(64, activation='relu', name='dense_3', kernel_initializer='glorot_uniform'))
model.add(Dense(1,name='predictions'))
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 750)               33000
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 750)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 375)               281625
# _________________________________________________________________
# predictions (Dense)          (None, 1)                 376
# =================================================================
# Total params: 315,001
# Trainable params: 315,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
from numpy import sqrt,asarray
model.compile(optimizer='adam', loss='mse', metrics=['mse','mae','mean_absolute_percentage_error'])

# %%
# Fit model with training data

history = model.fit(X_train, y_train, epochs=30, batch_size=5,  verbose=1, validation_split=0.2)
# Out:
# Train on 10833 samples, validate on 2709 samples
# Epoch 1/30
# 10833/10833 [==============================] - 9s 827us/step - loss: 6921.8665 - mse: 6921.8535 - mae: 24.7451 - mean_absolute_percentage_error: 61.0511 - val_loss: 13984.4688 - val_mse: 13984.4678 - val_mae: 22.6765 - val_mean_absolute_percentage_error: 47.8938
# Epoch 2/30
# 10833/10833 [==============================] - 9s 792us/step - loss: 6628.9449 - mse: 6628.9375 - mae: 24.2209 - mean_absolute_percentage_error: 59.2437 - val_loss: 13130.4902 - val_mse: 13130.4971 - val_mae: 24.0398 - val_mean_absolute_percentage_error: 56.2955
# Epoch 3/30
# 10833/10833 [==============================] - 9s 793us/step - loss: 6401.6866 - mse: 6401.6719 - mae: 24.2369 - mean_absolute_percentage_error: 58.5049 - val_loss: 12625.1807 - val_mse: 12625.1826 - val_mae: 23.8267 - val_mean_absolute_percentage_error: 59.9071
# Epoch 4/30
# 10833/10833 [==============================] - 10s 908us/step - loss: 6365.6541 - mse: 6365.6470 - mae: 23.9013 - mean_absolute_percentage_error: 57.6931 - val_loss: 11949.3128 - val_mse: 11949.3174 - val_mae: 22.5470 - val_mean_absolute_percentage_error: 50.5787
# Epoch 5/30
# 10833/10833 [==============================] - 10s 944us/step - loss: 6315.5527 - mse: 6315.5557 - mae: 23.8039 - mean_absolute_percentage_error: 57.7166 - val_loss: 11069.2327 - val_mse: 11069.2334 - val_mae: 23.4901 - val_mean_absolute_percentage_error: 56.0178
# Epoch 6/30
# 10833/10833 [==============================] - 11s 1ms/step - loss: 6208.2506 - mse: 6208.2510 - mae: 24.0311 - mean_absolute_percentage_error: 58.0077 - val_loss: 10765.2834 - val_mse: 10765.2842 - val_mae: 23.6388 - val_mean_absolute_percentage_error: 54.9035
# Epoch 7/30
# 10833/10833 [==============================] - 12s 1ms/step - loss: 6151.0438 - mse: 6151.0415 - mae: 23.6394 - mean_absolute_percentage_error: 56.9243 - val_loss: 10671.9345 - val_mse: 10671.9336 - val_mae: 32.8142 - val_mean_absolute_percentage_error: 99.9248
# Epoch 8/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6044.0727 - mse: 6044.0703 - mae: 24.0689 - mean_absolute_percentage_error: 57.4628 - val_loss: 10896.7069 - val_mse: 10896.7090 - val_mae: 27.3054 - val_mean_absolute_percentage_error: 79.5661
# Epoch 9/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6167.5053 - mse: 6167.5044 - mae: 24.0233 - mean_absolute_percentage_error: 58.6314 - val_loss: 10351.1112 - val_mse: 10351.1143 - val_mae: 22.9672 - val_mean_absolute_percentage_error: 54.3764
# Epoch 10/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6098.5481 - mse: 6098.5488 - mae: 23.5950 - mean_absolute_percentage_error: 56.5910 - val_loss: 10473.2140 - val_mse: 10473.2148 - val_mae: 23.1171 - val_mean_absolute_percentage_error: 56.5973
# Epoch 11/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6159.7791 - mse: 6159.7798 - mae: 23.4709 - mean_absolute_percentage_error: 56.5492 - val_loss: 9862.2127 - val_mse: 9862.2158 - val_mae: 22.9716 - val_mean_absolute_percentage_error: 52.5413
# Epoch 12/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6158.3366 - mse: 6158.3364 - mae: 23.4813 - mean_absolute_percentage_error: 56.3944 - val_loss: 9882.8115 - val_mse: 9882.8057 - val_mae: 22.7316 - val_mean_absolute_percentage_error: 52.0660
# Epoch 13/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6142.5951 - mse: 6142.5947 - mae: 23.2757 - mean_absolute_percentage_error: 55.1502 - val_loss: 10215.1277 - val_mse: 10215.1309 - val_mae: 29.1279 - val_mean_absolute_percentage_error: 87.4370
# Epoch 14/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6174.0517 - mse: 6174.0474 - mae: 23.6627 - mean_absolute_percentage_error: 57.4077 - val_loss: 10049.3762 - val_mse: 10049.3730 - val_mae: 23.1625 - val_mean_absolute_percentage_error: 56.9123
# Epoch 15/30
# 10833/10833 [==============================] - 14s 1ms/step - loss: 6157.5899 - mse: 6157.5864 - mae: 23.3390 - mean_absolute_percentage_error: 55.9336 - val_loss: 9981.9235 - val_mse: 9981.9170 - val_mae: 22.5188 - val_mean_absolute_percentage_error: 52.7330
# Epoch 16/30
# 10833/10833 [==============================] - 14s 1ms/step - loss: 5985.4004 - mse: 5985.3984 - mae: 23.2890 - mean_absolute_percentage_error: 56.3374 - val_loss: 9138.7392 - val_mse: 9138.7432 - val_mae: 30.6211 - val_mean_absolute_percentage_error: 86.8090
# Epoch 17/30
# 10833/10833 [==============================] - 14s 1ms/step - loss: 6065.9362 - mse: 6065.9316 - mae: 23.7007 - mean_absolute_percentage_error: 56.6233 - val_loss: 10333.2321 - val_mse: 10333.2275 - val_mae: 22.6429 - val_mean_absolute_percentage_error: 53.4842
# Epoch 18/30
# 10833/10833 [==============================] - 14s 1ms/step - loss: 6128.1554 - mse: 6128.1577 - mae: 23.4385 - mean_absolute_percentage_error: 55.9079 - val_loss: 10109.1568 - val_mse: 10109.1602 - val_mae: 22.6174 - val_mean_absolute_percentage_error: 52.5282
# Epoch 19/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6103.6433 - mse: 6103.6445 - mae: 23.3927 - mean_absolute_percentage_error: 56.1740 - val_loss: 10104.0282 - val_mse: 10104.0254 - val_mae: 23.1952 - val_mean_absolute_percentage_error: 56.5938
# Epoch 20/30
# 10833/10833 [==============================] - 14s 1ms/step - loss: 6125.8577 - mse: 6125.8599 - mae: 23.2838 - mean_absolute_percentage_error: 55.7413 - val_loss: 10223.5084 - val_mse: 10223.5146 - val_mae: 23.1151 - val_mean_absolute_percentage_error: 57.1610
# Epoch 21/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6074.6943 - mse: 6074.6934 - mae: 23.2356 - mean_absolute_percentage_error: 55.9434 - val_loss: 10008.5328 - val_mse: 10008.5312 - val_mae: 24.2797 - val_mean_absolute_percentage_error: 63.5583
# Epoch 22/30
# 10833/10833 [==============================] - 14s 1ms/step - loss: 6148.9768 - mse: 6148.9766 - mae: 23.3914 - mean_absolute_percentage_error: 56.0899 - val_loss: 9527.0709 - val_mse: 9527.0664 - val_mae: 23.2011 - val_mean_absolute_percentage_error: 55.9762
# Epoch 23/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6146.9134 - mse: 6146.9102 - mae: 23.2636 - mean_absolute_percentage_error: 55.7620 - val_loss: 9699.5224 - val_mse: 9699.5186 - val_mae: 23.2949 - val_mean_absolute_percentage_error: 58.4445
# Epoch 24/30
# 10833/10833 [==============================] - 14s 1ms/step - loss: 6072.8163 - mse: 6072.8125 - mae: 23.3870 - mean_absolute_percentage_error: 56.3338 - val_loss: 9942.4784 - val_mse: 9942.4863 - val_mae: 22.4160 - val_mean_absolute_percentage_error: 51.9555
# Epoch 25/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6132.6187 - mse: 6132.6196 - mae: 23.2842 - mean_absolute_percentage_error: 56.3704 - val_loss: 9450.9108 - val_mse: 9450.9092 - val_mae: 23.5378 - val_mean_absolute_percentage_error: 58.1255
# Epoch 26/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6013.0533 - mse: 6013.0503 - mae: 23.4803 - mean_absolute_percentage_error: 56.4865 - val_loss: 10286.6726 - val_mse: 10286.6699 - val_mae: 22.6561 - val_mean_absolute_percentage_error: 55.0679
# Epoch 27/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6070.9588 - mse: 6070.9585 - mae: 23.3423 - mean_absolute_percentage_error: 56.3854 - val_loss: 9872.9206 - val_mse: 9872.9180 - val_mae: 23.2980 - val_mean_absolute_percentage_error: 58.1980
# Epoch 28/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6074.1681 - mse: 6074.1699 - mae: 23.4942 - mean_absolute_percentage_error: 56.6865 - val_loss: 9554.4034 - val_mse: 9554.4053 - val_mae: 22.3142 - val_mean_absolute_percentage_error: 52.1102
# Epoch 29/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6038.5877 - mse: 6038.5879 - mae: 23.3713 - mean_absolute_percentage_error: 56.3798 - val_loss: 10334.8973 - val_mse: 10334.9004 - val_mae: 22.3338 - val_mean_absolute_percentage_error: 49.1301
# Epoch 30/30
# 10833/10833 [==============================] - 13s 1ms/step - loss: 6104.7999 - mse: 6104.7983 - mae: 23.3877 - mean_absolute_percentage_error: 56.3077 - val_loss: 10526.5398 - val_mse: 10526.5400 - val_mae: 22.7926 - val_mean_absolute_percentage_error: 54.8598

# %%
# Evaluate error and print MSE, MAE and Mean Absolute Percentage Error
error = model.evaluate(X_test, y_test, verbose=2)

print(f"MSE: {error[0]}")
print(f"MAE: {error[1]}")
print(f"RMSE: {sqrt(error[0])}")
print(f"Mean Absolute Percentage Error: {error[2]}")
# Out:
# MSE: 1216.5940115138076
# MAE: 1216.5938720703125
# RMSE: 34.8797077326317
# Mean Absolute Percentage Error: 20.666616439819336

# %%
# Build plot of training loss and validation loss

# print(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Compare one sample y with a predicted y
test_data = X_test[0]
pred = (model.predict(test_data.reshape(1,43)))
print(f"Predicted Price: {pred}")
print(f"Predicted Rating and Region {ohe.inverse_transform(X_test[0].reshape(1,-1))}")
print('---------------------------------------------------------------------------')
print(f"Actual Price: {y[0]}")
print(f"Actual Rating: {X.rating[1]}")
print(f"Actual Region: {X.region[1]}")
# Out:
# Predicted Price: [[30.64301]]
# Predicted Rating and Region [[88 'Bordeaux']]
# ---------------------------------------------------------------------------
# Actual Price: 185.0
# Actual Rating: 94
# Actual Region: California

# %%
# Save model
model.save('model_us_french_Cab_Bords_OHE_region.h5')

# %%
# Load old model for testing
from tensorflow.keras.models import load_model
# old_model = load_model('model_us_french_Cab_Bords_OHE_region.h5')

# %%
# Show one X value from OHE version of list of possible rate / region combos
test = np.expand_dims(X_ohe[0], axis=0)

# %%
# Make predictions on original dataset
predict_dataset = model.predict(X_ohe)
predict_dataset
# print(predict_dataset.shape)
# Out:
# array([[115.83967 ],
#        [100.83468 ],
#        [100.83468 ],
#        ...,
#        [ 14.977701],
#        [ 27.91658 ],
#        [ 30.84146 ]], dtype=float32)

# %%
# Add predicted price to dataframe
df["predicted price"] = predict_dataset
combo_df = df
# combo_df

# %%
combo_df.to_csv("Cab_Bords_Actual_Pred_region.csv", index=False)

# %%
# Inverse_transform list of possible rate / region combos
prediction_list = ohe.inverse_transform(predict_X_ohe)
# prediction_list

# %%
# Use model to make price predictions from list of possible rate / region combos
predicted_prices = model.predict(predict_X_ohe)
# predicted_prices

# %%
# Concat predicted prices with associated predicted rating and subregion from original prediction list

predicted_df = pd.DataFrame(np.concatenate((prediction_list, predicted_prices), axis=1))
predicted_df = predicted_df.rename(columns={0: "rating", 1: "region", 2: "predicted_"})
# predicted_df

# %%
predicted_df.to_csv("Cab_Bords_Predictions_region.csv", index=False)
